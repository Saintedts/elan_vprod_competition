# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split

import ast

# %%
idf = pd.read_csv('data/TRAIN_SAL.csv')
idf.head(100)
# Out:
# /tmp/ipykernel_68160/376317890.py:1: DtypeWarning: Columns (1,16,24,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf = pd.read_csv('TRAIN_SAL.csv')
#                                       id  ...                                         softSkills
# 0   4e2f52d2-fd76-11e4-8a5b-3bdbd1a6e39d  ...                                                 []
# 1   fafe2e23-0e2c-11e5-9cc4-3bdbd1a6e39d  ...                                                 []
# 2   7eb9edc1-fd76-11e4-8a5b-3bdbd1a6e39d  ...                                                 []
# 3   2e68ddc3-0499-11e5-b3df-3bdbd1a6e39d  ...                                                 []
# 4   8460a3b2-fd7e-11e4-8a5b-3bdbd1a6e39d  ...                                                 []
# ..                                   ...  ...                                                ...
# 95  a902d967-35e4-11e5-a8c4-239645b044d5  ...                                                 []
# 96  a5532597-35e9-11e5-a8c4-239645b044d5  ...                                                 []
# 97  8749da83-3661-11e5-a0ef-3bdbd1a6e39d  ...                                                 []
# 98  18649bd6-366d-11e5-a8c4-239645b044d5  ...                                                 []
# 99  bfa87cf6-36bc-11e5-a8c4-239645b044d5  ...  [{"owner_id":"bfa87cf6-36bc-11e5-a8c4-239645b0...
#
# [100 rows x 78 columns]

# %%
df = idf

# %%
print(len(df['code_profession'].unique()))
print(len(df['code_professional_sphere'].unique()))
# Out:
# 4424
# 35

# %%
len(df)
# Out:
# 631117

# %%
###preprocess data
def tokenize(vacancy_name):
    # Tokenize the vacancy name using regular expressions
    return set(re.split(r'[^\w]+', vacancy_name.lower()))

def compute_token_intersections(tokens1, tokens2):
    # Compute the intersection score between two sets of tokens
    return len(tokens1 & tokens2)

tokens_dict_profession = {}
code_profession_dict = {}


def impute_values(df, is_train, train_df=None):
    global tokens_dict_profession, code_profession_dict
    if is_train:
        # Handling 'code_profession'
        non_nan_train = train_df[train_df['code_profession'].notna()]
        vacancy_to_code_profession = non_nan_train.set_index('vacancy_name')['code_profession'].to_dict()
        df['code_profession'] = df['vacancy_name'].map(vacancy_to_code_profession).fillna(df['code_profession'])

        for index, row in df[df['code_profession'].notna()].iterrows():
            tokens_dict_profession[index] = tokenize(row['vacancy_name'])
            code_profession_dict[index] = row['code_profession']

        for index, row in df[df['code_profession'].isna()].iterrows():
            current_tokens = tokenize(row['vacancy_name'])
            max_intersection = 0
            best_match = None

            for other_index, other_tokens in tokens_dict_profession.items():
                intersection_score = compute_token_intersections(current_tokens, other_tokens)

                if intersection_score > max_intersection:
                    max_intersection = intersection_score
                    best_match = code_profession_dict[other_index]
                if intersection_score == 2 or intersection_score == len(current_tokens):
                    break

            df.at[index, 'code_profession'] = best_match

        df['code_profession'].fillna(df['code_profession'].median(), inplace=True)

        # Train set imputation for 'code_professional_sphere'
        non_nan_train = train_df[train_df['code_professional_sphere'].notna()]
        vacancy_to_code_professional_sphere = non_nan_train.set_index('vacancy_name')['code_professional_sphere'].to_dict()

        df['code_professional_sphere'] = df['vacancy_name'].map(vacancy_to_code_professional_sphere).fillna(df['code_professional_sphere'])

        tokens_dict_professional_sphere = {}
        code_professional_sphere_dict = {}

        for index, row in df[df['code_professional_sphere'].notna()].iterrows():
            tokens_dict_professional_sphere[index] = tokenize(row['vacancy_name'])
            code_professional_sphere_dict[index] = row['code_professional_sphere']

        for index, row in df[df['code_professional_sphere'].isna()].iterrows():
            current_tokens = tokenize(row['vacancy_name'])
            max_intersection = 0
            best_match = None

            for other_index, other_tokens in tokens_dict_professional_sphere.items():
                intersection_score = compute_token_intersections(current_tokens, other_tokens)

                if intersection_score > max_intersection:
                    max_intersection = intersection_score
                    best_match = code_professional_sphere_dict[other_index]
                if intersection_score == 2 or intersection_score == len(current_tokens):
                    break

            df.at[index, 'code_professional_sphere'] = best_match

        return df

    else:
        # Test set imputation based on train_df
        if train_df is None:
            raise ValueError("train_df must be provided for test set imputation")

        # Handling 'code_profession'
        non_nan_train = train_df[train_df['code_profession'].notna()]
        vacancy_to_code_profession = non_nan_train.set_index('vacancy_name')['code_profession'].to_dict()

        df['code_profession'] = df['vacancy_name'].map(vacancy_to_code_profession)
        #print(df['code_profession'])
        #df['code_profession'].fillna(df['code_profession'].apply(
        #    lambda x: find_best_match(x, tokens_dict_profession, code_profession_dict)), inplace=True)
        # Handling 'code_professional_sphere'
        non_nan_train = train_df[train_df['code_professional_sphere'].notna()]
        vacancy_to_code_professional_sphere = non_nan_train.set_index('vacancy_name')['code_professional_sphere'].to_dict()

        df['code_professional_sphere'] = df['vacancy_name'].map(vacancy_to_code_professional_sphere)
        #df['code_professional_sphere'].fillna(df['code_professional_sphere'].apply(
        #    lambda x: find_best_match(x, tokens_dict_professional_sphere, code_professional_sphere_dict)), inplace=True)

        return df

def find_best_match(vacancy_name, tokens_dict, code_dict):
    current_tokens = tokenize(vacancy_name)
    max_intersection = 0
    best_match = None

    for other_index, other_tokens in tokens_dict.items():
        intersection_score = compute_token_intersections(current_tokens, other_tokens)

        if intersection_score > max_intersection:
            max_intersection = intersection_score
            best_match = code_dict[other_index]
        if intersection_score == 2 or intersection_score == len(current_tokens):
            break
    return best_match

categories_which_need_medcard = set()

def needs_medcard(category):
    return category in categories_which_need_medcard

def hash_col(df, col, N):
    cols = [col + "_" + str(i) for i in range(N)]

    # Preallocate a zero matrix
    result = np.zeros((df.shape[0], N), dtype=int)

    # Apply hash function and set the corresponding column to 1
    for idx, val in enumerate(df[col]):
        result[idx, hash(val) % N] = 1

    # Create DataFrame from the result matrix
    df_hash = pd.DataFrame(result, columns=cols)

    # Concatenate the new columns to the original DataFrame and drop the old column
    return pd.concat([df.drop(col, axis=1), df_hash], axis=1)


premium_scaler = None
experience_scaler = None
salary_scaler = None
places_scaler = None
encoders = {
    'academic_degree': OneHotEncoder(sparse=False, handle_unknown='ignore'),
    'accommodation_type': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'bonus_type': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'measure_type': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'busy_type': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'education': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'original_source_type': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'company_business_size': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'schedule_type': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'social_protected_ids': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'source_type': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'state_region_code': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'status': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'transport_compensation': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'vacancy_benefit_ids': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'professionalSphereName': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'federalDistrictCode': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'code_professional_sphere': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'required_drive_license': OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
    'languageKnowledge': OneHotEncoder(sparse_output=False, handle_unknown='ignore')
    
}


def encode_column_train(df, column_name, prefix):
    
    encoders[column_name].fit(df[[column_name]])
    encoded = encoders[column_name].transform(df[[column_name]])
    
    encoded_df = pd.DataFrame(encoded, columns=encoders[column_name].get_feature_names_out([prefix]))
    
    # Ensure the encoded DataFrame has the same index as the original
    encoded_df.index = df.index
    
    return encoded_df


def encode_column(df, column_name, prefix):
    encoded = encoders[column_name].transform(df[[column_name]])
    
    encoded_df = pd.DataFrame(encoded, columns=encoders[column_name].get_feature_names_out([prefix]))
    
    # Ensure the encoded DataFrame has the same index as the original
    encoded_df.index = df.index
    
    return encoded_df


def explode_and_encode_train(df, column_name, prefix, value=None):
    df[column_name] = df[column_name].apply(ast.literal_eval)
    if value is not None:
        exploded = df[column_name].apply(lambda x: [d[value] for d in x]).explode()
    else:
        exploded = df[column_name].explode()
    encoded = encoders[column_name].fit_transform(exploded.values.reshape(-1, 1))
    encoded_df = pd.DataFrame(encoded, columns=encoders[column_name].get_feature_names_out([prefix]))
    return encoded_df.groupby(level=0).sum()


def explode_and_encode(df, column_name, prefix, value=None):
    df[column_name] = df[column_name].apply(ast.literal_eval)
    if value is not None:
        exploded = df[column_name].apply(lambda x: [d[value] for d in x]).explode()
    else:
        exploded = df[column_name].explode()
    encoded = encoders[column_name].transform(exploded.values.reshape(-1, 1))
    encoded_df = pd.DataFrame(encoded, columns=encoders[column_name].get_feature_names_out([prefix]))
    return encoded_df.groupby(level=0).sum()


def preprocess(df, is_train: bool = True, train_df: pd.DataFrame = None):
    global categories_which_need_medcard, premium_scaler, experience_scaler, salary_scaler, places_scaler
    # Drop unnecessary columns
    df = df.drop('id', axis=1)
    df = df.drop('contact_person', axis=1)
    df = df.drop('deleted', axis=1)
    df = df.drop('metro_ids', axis=1)
    df = df.drop('is_moderated', axis=1)
    df = df.drop('regionNameTerm', axis=1)
    df = df.drop('company_name', axis=1)
    df = df.drop('contact_source', axis=1)
    df = df.drop('data_ids', axis=1)
    df = df.drop('foreign_workers_capability', axis=1)
    df = df.drop('is_uzbekistan_recruitment', axis=1)
    df = df.drop('oknpo_code', axis=1)
    df = df.drop('okso_code', axis=1)
    df = df.drop('publication_period', axis=1)
    df = df.drop('contactList', axis=1)
    df = df.drop('regionName', axis=1)
    df = df.drop('retraining_capability', axis=1)
    df = df.drop('retraining_condition', axis=1)
    df = df.drop('retraining_grant_value', axis=1)
    df = df.drop('vacancy_address_additional_info',axis=1)
    df = df.drop('vacancy_address',axis=1)
    df = df.drop('vacancy_address_code',axis=1)
    df = df.drop('vacancy_address_house',axis=1)
    df = df.drop('vacancy_address_latitude',axis=1)
    df = df.drop('vacancy_address_longitude',axis=1)
    df = df.drop('industryBranchName',axis=1)
    df = df.drop('full_company_name',axis=1)
    df = df.drop('company_inn',axis=1)
    df = df.drop('company',axis=1)
    df = df.drop('company_code',axis=1)
    df = df.drop('code_external_system',axis=1)
    df = df.drop('visibility',axis=1)
    df = df.drop('additional_requirements', axis=1)
    df = df.drop('education_speciality', axis=1)
    df = df.drop('other_vacancy_benefit', axis=1)
    df = df.drop('position_requirements', axis=1)
    df = df.drop('position_responsibilities', axis=1)
    df = df.drop('required_certificates', axis=1)
    df = df.drop('hardSkills', axis=1)
    df = df.drop('softSkills', axis=1)
    
    ## Trying without date
    df = df.drop('change_time', axis=1)
    df = df.drop('date_create', axis=1)
    df = df.drop('date_modify', axis=1)
    df = df.drop('published_date', axis=1)
    
    
    
    # Deal with NaN
    df['academic_degree'].fillna('absent', inplace=True)
    df['accommodation_type'].fillna('absent', inplace=True)
    #df['additional_requirements'].fillna('absent', inplace=True)
    df['bonus_type'].fillna('absent', inplace=True)
    df['measure_type'].fillna('absent', inplace=True)
    #df['education_speciality'].fillna('absent', inplace=True)
    #df['other_vacancy_benefit'].fillna('absent', inplace=True)
    #df['position_requirements'].fillna('absent', inplace=True)
    #df['position_responsibilities'].fillna('absent', inplace=True)
    #df['required_certificates'].fillna('absent', inplace=True)
    df['social_protected_ids'].fillna('absent', inplace=True)
    df['transport_compensation'].fillna('absent', inplace=True)
    df['vacancy_benefit_ids'].fillna('absent', inplace=True)
    df['professionalSphereName'].fillna('absent', inplace=True)
    df['is_mobility_program'].fillna(False, inplace=True)
    df['additional_premium'].fillna(0, inplace=True)
    df['required_experience'].fillna(0, inplace=True)
    if is_train:
        df = impute_values(df,is_train=True, train_df=df)
    else:
        df = impute_values(df,is_train=False,train_df=train_df)
    categories_which_need_medcard = set(df[df['need_medcard'] == True]['code_professional_sphere'])
    df['need_medcard'] = df['need_medcard'].fillna(df['code_professional_sphere'].apply(needs_medcard))
        
    ### Transform
    df['accommodation_capability'] = df['accommodation_capability'].astype(int)
    df['career_perspective'] = df['career_perspective'].astype(int)
    df['is_mobility_program'] = df['is_mobility_program'].astype(int)
    df['is_quoted'] = df['is_quoted'].astype(int)
    df['need_medcard'] = df['need_medcard'].astype(int)
    df['retraining_grant'] = df['retraining_grant'].replace({'нет стипендии': 0, 'есть стипендия': 1})
    n_features = 100
    if is_train:
        df = df.dropna(subset=['state_region_code'])
        df = df.dropna(subset=['federalDistrictCode'])
        df = df.loc[df['salary'] <= 400000]
        df = pd.concat([df.drop('academic_degree',axis=1),encode_column_train(df, 'academic_degree', 'academic_degree')],axis=1)
        df = pd.concat([df.drop('accommodation_type',axis=1),encode_column_train(df, 'accommodation_type', 'accommodation_type')],axis=1)
        df = pd.concat([df.drop('bonus_type',axis=1),encode_column_train(df, 'bonus_type', 'bonus_type')],axis=1)
        df = pd.concat([df.drop('measure_type',axis=1),encode_column_train(df, 'measure_type', 'measure_type')],axis=1)
        df = pd.concat([df.drop('busy_type',axis=1),encode_column_train(df, 'busy_type', 'busy_type')],axis=1)
        df = pd.concat([df.drop('education',axis=1),encode_column_train(df, 'education', 'education')],axis=1)
        df = pd.concat([df.drop('original_source_type',axis=1),encode_column_train(df, 'original_source_type', 'original_source_type')],axis=1)
        df = pd.concat([df.drop('company_business_size',axis=1),encode_column_train(df, 'company_business_size', 'company_business_size')],axis=1)
        df = pd.concat([df.drop('schedule_type',axis=1),encode_column_train(df, 'schedule_type', 'schedule_type')],axis=1)
        df = pd.concat([df.drop('social_protected_ids',axis=1),encode_column_train(df, 'social_protected_ids', 'social_protected_ids')],axis=1)
        df = pd.concat([df.drop('source_type',axis=1),encode_column_train(df, 'source_type', 'source_type')],axis=1)
        df = pd.concat([df.drop('state_region_code',axis=1),encode_column_train(df, 'state_region_code', 'state_region_code')],axis=1)
        df = pd.concat([df.drop('status',axis=1),encode_column_train(df, 'status', 'status')],axis=1)
        df = pd.concat([df.drop('transport_compensation',axis=1),encode_column_train(df, 'transport_compensation', 'transport_compensation')],axis=1)
        df = pd.concat([df.drop('vacancy_benefit_ids',axis=1),encode_column_train(df, 'vacancy_benefit_ids', 'vacancy_benefit_ids')],axis=1)
        df = pd.concat([df.drop('professionalSphereName',axis=1),encode_column_train(df, 'professionalSphereName', 'professionalSphereName')],axis=1)
        df = pd.concat([df.drop('federalDistrictCode',axis=1),encode_column_train(df, 'federalDistrictCode', 'federalDistrictCode')],axis=1)
        df = pd.concat([df.drop('code_professional_sphere',axis=1),encode_column_train(df, 'code_professional_sphere', 'code_professional_sphere')],axis=1)
        encoded_required_drive_license = explode_and_encode_train(df, 'required_drive_license', 'required_drive_license')
        encoded_languageKnowledge = explode_and_encode_train(df, 'languageKnowledge', 'languageKnowledge', 'code_language')
        df = pd.concat([df.drop(columns=['required_drive_license', 'languageKnowledge']), 
                        encoded_required_drive_license, 
                        encoded_languageKnowledge], axis=1)
        
        premium_scaler = StandardScaler()
        df['additional_premium'] = premium_scaler.fit_transform(np.array(df['additional_premium']).reshape(-1,1))
        experience_scaler = StandardScaler()
        df['required_experience'] = experience_scaler.fit_transform(np.array(df['required_experience']).reshape(-1,1))
        
        mean_salary_max = df.loc[df['salary_max'] > 0, 'salary_max'].mean()
        df['salary_max'] = df['salary_max'].replace(0, mean_salary_max)
        df.loc[df['salary'] == 0, 'salary'] = df['salary_max']
        salary_scaler = StandardScaler()
        df['salary'] = salary_scaler.fit_transform(np.array(df['salary']).reshape(-1,1))
        places_scaler = StandardScaler()
        df['work_places'] = places_scaler.fit_transform(np.array(df['work_places']).reshape(-1,1))
        df = hash_col(df, 'code_profession',100)
        df = df.dropna()
    else:
        df = df.fillna(train_df.median())
        df = pd.concat([df.drop('academic_degree',axis=1),encode_column(df, 'academic_degree', 'academic_degree')],axis=1)
        df = pd.concat([df.drop('accommodation_type',axis=1),encode_column(df, 'accommodation_type', 'accommodation_type')],axis=1)
        df = pd.concat([df.drop('bonus_type',axis=1),encode_column(df, 'bonus_type', 'bonus_type')],axis=1)
        df = pd.concat([df.drop('measure_type',axis=1),encode_column(df, 'measure_type', 'measure_type')],axis=1)
        df = pd.concat([df.drop('busy_type',axis=1),encode_column(df, 'busy_type', 'busy_type')],axis=1)
        df = pd.concat([df.drop('education',axis=1),encode_column(df, 'education', 'education')],axis=1)
        df = pd.concat([df.drop('original_source_type',axis=1),encode_column(df, 'original_source_type', 'original_source_type')],axis=1)
        df = pd.concat([df.drop('company_business_size',axis=1),encode_column(df, 'company_business_size', 'company_business_size')],axis=1)
        df = pd.concat([df.drop('schedule_type',axis=1),encode_column(df, 'schedule_type', 'schedule_type')],axis=1)
        df = pd.concat([df.drop('social_protected_ids',axis=1),encode_column(df, 'social_protected_ids', 'social_protected_ids')],axis=1)
        df = pd.concat([df.drop('source_type',axis=1),encode_column(df, 'source_type', 'source_type')],axis=1)
        df = pd.concat([df.drop('state_region_code',axis=1),encode_column(df, 'state_region_code', 'state_region_code')],axis=1)
        df = pd.concat([df.drop('status',axis=1),encode_column(df, 'status', 'status')],axis=1)
        df = pd.concat([df.drop('transport_compensation',axis=1),encode_column(df, 'transport_compensation', 'transport_compensation')],axis=1)
        df = pd.concat([df.drop('vacancy_benefit_ids',axis=1),encode_column(df, 'vacancy_benefit_ids', 'vacancy_benefit_ids')],axis=1)
        df = pd.concat([df.drop('professionalSphereName',axis=1),encode_column(df, 'professionalSphereName', 'professionalSphereName')],axis=1)
        df = pd.concat([df.drop('federalDistrictCode',axis=1),encode_column(df, 'federalDistrictCode', 'federalDistrictCode')],axis=1)
        df = pd.concat([df.drop('code_professional_sphere',axis=1),encode_column(df, 'code_professional_sphere', 'code_professional_sphere')],axis=1)
        encoded_required_drive_license = explode_and_encode(df, 'required_drive_license', 'required_drive_license')
        encoded_languageKnowledge = explode_and_encode(df, 'languageKnowledge', 'languageKnowledge', 'code_language')
        df = pd.concat([df.drop(columns=['required_drive_license', 'languageKnowledge']),
                        encoded_required_drive_license, 
                        encoded_languageKnowledge], axis=1)
        df['additional_premium'] = premium_scaler.transform(np.array(df['additional_premium']).reshape(-1,1))
        df['required_experience'] = experience_scaler.transform(np.array(df['required_experience']).reshape(-1,1))
        df['work_places'] = places_scaler.transform(np.array(df['work_places']).reshape(-1,1))
        df = hash_col(df, 'code_profession',100)
        df = df.fillna(0)
    df = df.drop('vacancy_name', axis=1)
    if is_train or 'salary_min' in df.columns:
        df = df.drop('salary_min', axis=1)
        df = df.drop('salary_max', axis=1)

    return df

print('train')
df = preprocess(df)

df.head()
# Out:
# train
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#    accommodation_capability  ...  code_profession_99
# 0                       0.0  ...                   0
# 1                       0.0  ...                   0
# 2                       0.0  ...                   0
# 3                       0.0  ...                   0
# 4                       0.0  ...                   0
#
# [5 rows x 544 columns]

# %%
df_test = preprocess(test,is_train=False,train_df=train)
df_test.head()
# Out:
# /tmp/ipykernel_58606/3588265191.py:338: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.fillna(train_df.median())
#         accommodation_capability  ...  code_profession_99
# 326087                       0.0  ...                 0.0
# 412259                       0.0  ...                 0.0
# 297576                       0.0  ...                 0.0
# 139489                       0.0  ...                 0.0
# 270023                       0.0  ...                 0.0
#
# [5 rows x 526 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor, Pool


X_train = df.drop('salary',axis=1)
y_train = df['salary']

model = CatBoostRegressor(
    iterations=1000,
    depth=16,
    learning_rate=0.15,
    loss_function='RMSE',
    gpu_ram_part=0.8,
    task_type='GPU',
    snapshot_interval=1000,
)
print('start training')
model.fit(X_train, y_train)
print('trained')
# Out:
# start training
# 0:	learn: 0.9413697	total: 236ms	remaining: 3m 55s
# 1:	learn: 0.9022081	total: 372ms	remaining: 3m 5s
# 2:	learn: 0.8717755	total: 507ms	remaining: 2m 48s
# 3:	learn: 0.8474904	total: 641ms	remaining: 2m 39s
# 4:	learn: 0.8286793	total: 778ms	remaining: 2m 34s
# 5:	learn: 0.8132748	total: 914ms	remaining: 2m 31s
# 6:	learn: 0.8007073	total: 1.05s	remaining: 2m 28s
# 7:	learn: 0.7890167	total: 1.18s	remaining: 2m 26s
# 8:	learn: 0.7793702	total: 1.32s	remaining: 2m 25s
# 9:	learn: 0.7712230	total: 1.45s	remaining: 2m 23s
# 10:	learn: 0.7641457	total: 1.59s	remaining: 2m 23s
# 11:	learn: 0.7580731	total: 1.73s	remaining: 2m 22s
# 12:	learn: 0.7516281	total: 1.86s	remaining: 2m 21s
# 13:	learn: 0.7466089	total: 1.99s	remaining: 2m 20s
# 14:	learn: 0.7412417	total: 2.13s	remaining: 2m 19s
# 15:	learn: 0.7373942	total: 2.26s	remaining: 2m 19s
# 16:	learn: 0.7333006	total: 2.4s	remaining: 2m 18s
# 17:	learn: 0.7300086	total: 2.53s	remaining: 2m 18s
# 18:	learn: 0.7262794	total: 2.67s	remaining: 2m 17s
# 19:	learn: 0.7233383	total: 2.8s	remaining: 2m 17s
# 20:	learn: 0.7209674	total: 2.93s	remaining: 2m 16s
# 21:	learn: 0.7182912	total: 3.07s	remaining: 2m 16s
# 22:	learn: 0.7147285	total: 3.2s	remaining: 2m 16s
# 23:	learn: 0.7110513	total: 3.34s	remaining: 2m 15s
# 24:	learn: 0.7088394	total: 3.47s	remaining: 2m 15s
# 25:	learn: 0.7070577	total: 3.61s	remaining: 2m 15s
# 26:	learn: 0.7055043	total: 3.74s	remaining: 2m 14s
# 27:	learn: 0.7028108	total: 3.88s	remaining: 2m 14s
# 28:	learn: 0.6997681	total: 4.01s	remaining: 2m 14s
# 29:	learn: 0.6983270	total: 4.15s	remaining: 2m 14s
# 30:	learn: 0.6962253	total: 4.28s	remaining: 2m 13s
# 31:	learn: 0.6941520	total: 4.42s	remaining: 2m 13s
# 32:	learn: 0.6930419	total: 4.57s	remaining: 2m 13s
# 33:	learn: 0.6917267	total: 4.7s	remaining: 2m 13s
# 34:	learn: 0.6904627	total: 4.84s	remaining: 2m 13s
# 35:	learn: 0.6890624	total: 4.97s	remaining: 2m 13s
# 36:	learn: 0.6877831	total: 5.11s	remaining: 2m 12s
# 37:	learn: 0.6863502	total: 5.24s	remaining: 2m 12s
# 38:	learn: 0.6845311	total: 5.38s	remaining: 2m 12s
# 39:	learn: 0.6831910	total: 5.51s	remaining: 2m 12s
# 40:	learn: 0.6823077	total: 5.64s	remaining: 2m 11s
# 41:	learn: 0.6809898	total: 5.78s	remaining: 2m 11s
# 42:	learn: 0.6798599	total: 5.91s	remaining: 2m 11s
# 43:	learn: 0.6788885	total: 6.05s	remaining: 2m 11s
# 44:	learn: 0.6780344	total: 6.18s	remaining: 2m 11s
# 45:	learn: 0.6772159	total: 6.32s	remaining: 2m 10s
# 46:	learn: 0.6764712	total: 6.45s	remaining: 2m 10s
# 47:	learn: 0.6757132	total: 6.58s	remaining: 2m 10s
# 48:	learn: 0.6747118	total: 6.72s	remaining: 2m 10s
# 49:	learn: 0.6739470	total: 6.85s	remaining: 2m 10s
# 50:	learn: 0.6729961	total: 6.99s	remaining: 2m 10s
# 51:	learn: 0.6718243	total: 7.12s	remaining: 2m 9s
# 52:	learn: 0.6709124	total: 7.26s	remaining: 2m 9s
# 53:	learn: 0.6694083	total: 7.39s	remaining: 2m 9s
# 54:	learn: 0.6687248	total: 7.53s	remaining: 2m 9s
# 55:	learn: 0.6675304	total: 7.66s	remaining: 2m 9s
# 56:	learn: 0.6666818	total: 7.8s	remaining: 2m 9s
# 57:	learn: 0.6659378	total: 7.93s	remaining: 2m 8s
# 58:	learn: 0.6653587	total: 8.07s	remaining: 2m 8s
# 59:	learn: 0.6643252	total: 8.2s	remaining: 2m 8s
# 60:	learn: 0.6635222	total: 8.34s	remaining: 2m 8s
# 61:	learn: 0.6625589	total: 8.47s	remaining: 2m 8s
# 62:	learn: 0.6617189	total: 8.6s	remaining: 2m 7s
# 63:	learn: 0.6610436	total: 8.74s	remaining: 2m 7s
# 64:	learn: 0.6603393	total: 8.91s	remaining: 2m 8s
# 65:	learn: 0.6597096	total: 9.04s	remaining: 2m 7s
# 66:	learn: 0.6587918	total: 9.18s	remaining: 2m 7s
# 67:	learn: 0.6583897	total: 9.31s	remaining: 2m 7s
# 68:	learn: 0.6573411	total: 9.45s	remaining: 2m 7s
# 69:	learn: 0.6564217	total: 9.58s	remaining: 2m 7s
# 70:	learn: 0.6558250	total: 9.71s	remaining: 2m 7s
# 71:	learn: 0.6554017	total: 9.85s	remaining: 2m 6s
# 72:	learn: 0.6547257	total: 9.98s	remaining: 2m 6s
# 73:	learn: 0.6540815	total: 10.1s	remaining: 2m 6s
# 74:	learn: 0.6533356	total: 10.3s	remaining: 2m 6s
# 75:	learn: 0.6523854	total: 10.4s	remaining: 2m 6s
# 76:	learn: 0.6517481	total: 10.5s	remaining: 2m 6s
# 77:	learn: 0.6511602	total: 10.7s	remaining: 2m 5s
# 78:	learn: 0.6506328	total: 10.8s	remaining: 2m 5s
# 79:	learn: 0.6500257	total: 10.9s	remaining: 2m 5s
# 80:	learn: 0.6492657	total: 11.1s	remaining: 2m 5s
# 81:	learn: 0.6487587	total: 11.2s	remaining: 2m 5s
# 82:	learn: 0.6482512	total: 11.3s	remaining: 2m 5s
# 83:	learn: 0.6474202	total: 11.5s	remaining: 2m 5s
# 84:	learn: 0.6468670	total: 11.6s	remaining: 2m 4s
# 85:	learn: 0.6462297	total: 11.7s	remaining: 2m 4s
# 86:	learn: 0.6457579	total: 11.9s	remaining: 2m 4s
# 87:	learn: 0.6447584	total: 12s	remaining: 2m 4s
# 88:	learn: 0.6442619	total: 12.1s	remaining: 2m 4s
# 89:	learn: 0.6434179	total: 12.3s	remaining: 2m 4s
# 90:	learn: 0.6425842	total: 12.4s	remaining: 2m 3s
# 91:	learn: 0.6419692	total: 12.5s	remaining: 2m 3s
# 92:	learn: 0.6415412	total: 12.7s	remaining: 2m 3s
# 93:	learn: 0.6410550	total: 12.8s	remaining: 2m 3s
# 94:	learn: 0.6404530	total: 12.9s	remaining: 2m 3s
# 95:	learn: 0.6398742	total: 13.1s	remaining: 2m 3s
# 96:	learn: 0.6388904	total: 13.2s	remaining: 2m 3s
# 97:	learn: 0.6382707	total: 13.4s	remaining: 2m 2s
# 98:	learn: 0.6378310	total: 13.5s	remaining: 2m 2s
# 99:	learn: 0.6372960	total: 13.6s	remaining: 2m 2s
# 100:	learn: 0.6368705	total: 13.8s	remaining: 2m 2s
# 101:	learn: 0.6364501	total: 13.9s	remaining: 2m 2s
# 102:	learn: 0.6361001	total: 14s	remaining: 2m 2s
# 103:	learn: 0.6356322	total: 14.2s	remaining: 2m 1s
# 104:	learn: 0.6353277	total: 14.3s	remaining: 2m 1s
# 105:	learn: 0.6349144	total: 14.4s	remaining: 2m 1s
# 106:	learn: 0.6344164	total: 14.6s	remaining: 2m 1s
# 107:	learn: 0.6341483	total: 14.7s	remaining: 2m 1s
# 108:	learn: 0.6336766	total: 14.8s	remaining: 2m 1s
# 109:	learn: 0.6331128	total: 15s	remaining: 2m 1s
# 110:	learn: 0.6326123	total: 15.1s	remaining: 2m
# 111:	learn: 0.6319770	total: 15.2s	remaining: 2m
# 112:	learn: 0.6315274	total: 15.4s	remaining: 2m
# 113:	learn: 0.6310625	total: 15.5s	remaining: 2m
# 114:	learn: 0.6306389	total: 15.6s	remaining: 2m
# 115:	learn: 0.6299763	total: 15.8s	remaining: 2m
# 116:	learn: 0.6293698	total: 15.9s	remaining: 2m
# 117:	learn: 0.6289247	total: 16s	remaining: 1m 59s
# 118:	learn: 0.6284896	total: 16.2s	remaining: 1m 59s
# 119:	learn: 0.6281584	total: 16.3s	remaining: 1m 59s
# 120:	learn: 0.6276404	total: 16.4s	remaining: 1m 59s
# 121:	learn: 0.6271450	total: 16.6s	remaining: 1m 59s
# 122:	learn: 0.6267862	total: 16.7s	remaining: 1m 59s
# 123:	learn: 0.6264556	total: 16.9s	remaining: 1m 59s
# 124:	learn: 0.6258013	total: 17s	remaining: 1m 58s
# 125:	learn: 0.6252744	total: 17.1s	remaining: 1m 58s
# 126:	learn: 0.6249200	total: 17.3s	remaining: 1m 58s
# 127:	learn: 0.6245459	total: 17.4s	remaining: 1m 58s
# 128:	learn: 0.6240414	total: 17.6s	remaining: 1m 58s
# 129:	learn: 0.6237405	total: 17.7s	remaining: 1m 58s
# 130:	learn: 0.6233689	total: 17.9s	remaining: 1m 58s
# 131:	learn: 0.6230339	total: 18s	remaining: 1m 58s
# 132:	learn: 0.6227083	total: 18.1s	remaining: 1m 58s
# 133:	learn: 0.6223682	total: 18.3s	remaining: 1m 58s
# 134:	learn: 0.6219040	total: 18.4s	remaining: 1m 57s
# 135:	learn: 0.6215364	total: 18.6s	remaining: 1m 57s
# 136:	learn: 0.6209869	total: 18.7s	remaining: 1m 57s
# 137:	learn: 0.6205432	total: 18.8s	remaining: 1m 57s
# 138:	learn: 0.6198411	total: 19s	remaining: 1m 57s
# 139:	learn: 0.6195184	total: 19.1s	remaining: 1m 57s
# 140:	learn: 0.6191367	total: 19.2s	remaining: 1m 57s
# 141:	learn: 0.6184348	total: 19.4s	remaining: 1m 57s
# 142:	learn: 0.6178810	total: 19.5s	remaining: 1m 56s
# 143:	learn: 0.6174290	total: 19.6s	remaining: 1m 56s
# 144:	learn: 0.6171162	total: 19.8s	remaining: 1m 56s
# 145:	learn: 0.6166690	total: 19.9s	remaining: 1m 56s
# 146:	learn: 0.6161104	total: 20s	remaining: 1m 56s
# 147:	learn: 0.6157916	total: 20.2s	remaining: 1m 56s
# 148:	learn: 0.6152287	total: 20.3s	remaining: 1m 56s
# 149:	learn: 0.6149291	total: 20.4s	remaining: 1m 55s
# 150:	learn: 0.6146602	total: 20.6s	remaining: 1m 55s
# 151:	learn: 0.6143520	total: 20.7s	remaining: 1m 55s
# 152:	learn: 0.6140556	total: 20.9s	remaining: 1m 55s
# 153:	learn: 0.6136136	total: 21s	remaining: 1m 55s
# 154:	learn: 0.6133582	total: 21.1s	remaining: 1m 55s
# 155:	learn: 0.6129878	total: 21.3s	remaining: 1m 55s
# 156:	learn: 0.6125873	total: 21.4s	remaining: 1m 54s
# 157:	learn: 0.6120956	total: 21.5s	remaining: 1m 54s
# 158:	learn: 0.6118416	total: 21.7s	remaining: 1m 54s
# 159:	learn: 0.6114716	total: 21.8s	remaining: 1m 54s
# 160:	learn: 0.6111696	total: 21.9s	remaining: 1m 54s
# 161:	learn: 0.6108170	total: 22.1s	remaining: 1m 54s
# 162:	learn: 0.6105391	total: 22.2s	remaining: 1m 54s
# 163:	learn: 0.6102891	total: 22.3s	remaining: 1m 53s
# 164:	learn: 0.6097746	total: 22.5s	remaining: 1m 53s
# 165:	learn: 0.6093924	total: 22.6s	remaining: 1m 53s
# 166:	learn: 0.6092106	total: 22.7s	remaining: 1m 53s
# 167:	learn: 0.6088854	total: 22.9s	remaining: 1m 53s
# 168:	learn: 0.6085120	total: 23s	remaining: 1m 53s
# 169:	learn: 0.6080181	total: 23.1s	remaining: 1m 53s
# 170:	learn: 0.6077689	total: 23.3s	remaining: 1m 52s
# 171:	learn: 0.6074123	total: 23.4s	remaining: 1m 52s
# 172:	learn: 0.6070745	total: 23.6s	remaining: 1m 52s
# 173:	learn: 0.6068495	total: 23.7s	remaining: 1m 52s
# 174:	learn: 0.6066066	total: 23.8s	remaining: 1m 52s
# 175:	learn: 0.6063856	total: 24s	remaining: 1m 52s
# 176:	learn: 0.6060054	total: 24.1s	remaining: 1m 52s
# 177:	learn: 0.6056168	total: 24.2s	remaining: 1m 51s
# 178:	learn: 0.6053986	total: 24.4s	remaining: 1m 51s
# 179:	learn: 0.6051167	total: 24.5s	remaining: 1m 51s
# 180:	learn: 0.6048803	total: 24.6s	remaining: 1m 51s
# 181:	learn: 0.6046401	total: 24.8s	remaining: 1m 51s
# 182:	learn: 0.6043207	total: 24.9s	remaining: 1m 51s
# 183:	learn: 0.6040648	total: 25s	remaining: 1m 51s
# 184:	learn: 0.6037515	total: 25.2s	remaining: 1m 50s
# 185:	learn: 0.6035450	total: 25.3s	remaining: 1m 50s
# 186:	learn: 0.6032564	total: 25.4s	remaining: 1m 50s
# 187:	learn: 0.6030000	total: 25.6s	remaining: 1m 50s
# 188:	learn: 0.6027427	total: 25.7s	remaining: 1m 50s
# 189:	learn: 0.6024835	total: 25.8s	remaining: 1m 50s
# 190:	learn: 0.6022203	total: 26s	remaining: 1m 50s
# 191:	learn: 0.6019151	total: 26.1s	remaining: 1m 49s
# 192:	learn: 0.6016798	total: 26.2s	remaining: 1m 49s
# 193:	learn: 0.6014626	total: 26.4s	remaining: 1m 49s
# 194:	learn: 0.6011459	total: 26.5s	remaining: 1m 49s
# 195:	learn: 0.6007955	total: 26.7s	remaining: 1m 49s
# 196:	learn: 0.6005973	total: 26.8s	remaining: 1m 49s
# 197:	learn: 0.6003700	total: 26.9s	remaining: 1m 49s
# 198:	learn: 0.5999715	total: 27.1s	remaining: 1m 48s
# 199:	learn: 0.5996678	total: 27.2s	remaining: 1m 48s
# 200:	learn: 0.5993436	total: 27.3s	remaining: 1m 48s
# 201:	learn: 0.5990009	total: 27.5s	remaining: 1m 48s
# 202:	learn: 0.5985955	total: 27.6s	remaining: 1m 48s
# 203:	learn: 0.5982541	total: 27.7s	remaining: 1m 48s
# 204:	learn: 0.5979138	total: 27.9s	remaining: 1m 48s
# 205:	learn: 0.5976409	total: 28s	remaining: 1m 47s
# 206:	learn: 0.5974647	total: 28.1s	remaining: 1m 47s
# 207:	learn: 0.5972601	total: 28.3s	remaining: 1m 47s
# 208:	learn: 0.5968957	total: 28.4s	remaining: 1m 47s
# 209:	learn: 0.5966898	total: 28.5s	remaining: 1m 47s
# 210:	learn: 0.5964254	total: 28.7s	remaining: 1m 47s
# 211:	learn: 0.5961944	total: 28.8s	remaining: 1m 47s
# 212:	learn: 0.5959848	total: 29s	remaining: 1m 46s
# 213:	learn: 0.5956394	total: 29.1s	remaining: 1m 46s
# 214:	learn: 0.5954868	total: 29.2s	remaining: 1m 46s
# 215:	learn: 0.5952004	total: 29.4s	remaining: 1m 46s
# 216:	learn: 0.5948397	total: 29.5s	remaining: 1m 46s
# 217:	learn: 0.5945685	total: 29.6s	remaining: 1m 46s
# 218:	learn: 0.5941656	total: 29.8s	remaining: 1m 46s
# 219:	learn: 0.5940562	total: 29.9s	remaining: 1m 45s
# 220:	learn: 0.5937567	total: 30s	remaining: 1m 45s
# 221:	learn: 0.5935095	total: 30.2s	remaining: 1m 45s
# 222:	learn: 0.5932862	total: 30.3s	remaining: 1m 45s
# 223:	learn: 0.5930758	total: 30.4s	remaining: 1m 45s
# 224:	learn: 0.5928010	total: 30.6s	remaining: 1m 45s
# 225:	learn: 0.5925833	total: 30.7s	remaining: 1m 45s
# 226:	learn: 0.5924066	total: 30.8s	remaining: 1m 45s
# 227:	learn: 0.5920763	total: 31s	remaining: 1m 44s
# 228:	learn: 0.5916978	total: 31.1s	remaining: 1m 44s
# 229:	learn: 0.5913139	total: 31.2s	remaining: 1m 44s
# 230:	learn: 0.5910007	total: 31.4s	remaining: 1m 44s
# 231:	learn: 0.5906804	total: 31.5s	remaining: 1m 44s
# 232:	learn: 0.5904960	total: 31.7s	remaining: 1m 44s
# 233:	learn: 0.5903014	total: 31.8s	remaining: 1m 44s
# 234:	learn: 0.5900240	total: 31.9s	remaining: 1m 43s
# 235:	learn: 0.5898251	total: 32.1s	remaining: 1m 43s
# 236:	learn: 0.5897277	total: 32.2s	remaining: 1m 43s
# 237:	learn: 0.5893556	total: 32.3s	remaining: 1m 43s
# 238:	learn: 0.5892024	total: 32.5s	remaining: 1m 43s
# 239:	learn: 0.5890339	total: 32.6s	remaining: 1m 43s
# 240:	learn: 0.5888815	total: 32.7s	remaining: 1m 43s
# 241:	learn: 0.5886576	total: 32.9s	remaining: 1m 42s
# 242:	learn: 0.5882690	total: 33s	remaining: 1m 42s
# 243:	learn: 0.5881205	total: 33.1s	remaining: 1m 42s
# 244:	learn: 0.5879653	total: 33.3s	remaining: 1m 42s
# 245:	learn: 0.5877669	total: 33.4s	remaining: 1m 42s
# 246:	learn: 0.5875812	total: 33.5s	remaining: 1m 42s
# 247:	learn: 0.5873826	total: 33.7s	remaining: 1m 42s
# 248:	learn: 0.5871937	total: 33.8s	remaining: 1m 41s
# 249:	learn: 0.5869997	total: 33.9s	remaining: 1m 41s
# 250:	learn: 0.5868346	total: 34.1s	remaining: 1m 41s
# 251:	learn: 0.5864751	total: 34.2s	remaining: 1m 41s
# 252:	learn: 0.5862304	total: 34.3s	remaining: 1m 41s
# 253:	learn: 0.5860301	total: 34.5s	remaining: 1m 41s
# 254:	learn: 0.5857726	total: 34.6s	remaining: 1m 41s
# 255:	learn: 0.5855355	total: 34.7s	remaining: 1m 40s
# 256:	learn: 0.5853878	total: 35s	remaining: 1m 41s
# 257:	learn: 0.5851634	total: 35.1s	remaining: 1m 41s
# 258:	learn: 0.5848758	total: 35.3s	remaining: 1m 40s
# 259:	learn: 0.5845129	total: 35.4s	remaining: 1m 40s
# 260:	learn: 0.5843206	total: 35.6s	remaining: 1m 40s
# 261:	learn: 0.5841946	total: 35.7s	remaining: 1m 40s
# 262:	learn: 0.5839918	total: 35.8s	remaining: 1m 40s
# 263:	learn: 0.5837322	total: 36s	remaining: 1m 40s
# 264:	learn: 0.5835112	total: 36.1s	remaining: 1m 40s
# 265:	learn: 0.5832283	total: 36.2s	remaining: 1m 39s
# 266:	learn: 0.5830743	total: 36.4s	remaining: 1m 39s
# 267:	learn: 0.5828790	total: 36.5s	remaining: 1m 39s
# 268:	learn: 0.5826067	total: 36.6s	remaining: 1m 39s
# 269:	learn: 0.5824989	total: 36.8s	remaining: 1m 39s
# 270:	learn: 0.5822827	total: 36.9s	remaining: 1m 39s
# 271:	learn: 0.5820574	total: 37s	remaining: 1m 39s
# 272:	learn: 0.5817965	total: 37.2s	remaining: 1m 38s
# 273:	learn: 0.5815353	total: 37.3s	remaining: 1m 38s
# 274:	learn: 0.5812614	total: 37.4s	remaining: 1m 38s
# 275:	learn: 0.5809594	total: 37.6s	remaining: 1m 38s
# 276:	learn: 0.5807513	total: 37.7s	remaining: 1m 38s
# 277:	learn: 0.5803599	total: 37.9s	remaining: 1m 38s
# 278:	learn: 0.5799993	total: 38s	remaining: 1m 38s
# 279:	learn: 0.5797189	total: 38.1s	remaining: 1m 38s
# 280:	learn: 0.5794299	total: 38.3s	remaining: 1m 37s
# 281:	learn: 0.5791844	total: 38.4s	remaining: 1m 37s
# 282:	learn: 0.5790169	total: 38.5s	remaining: 1m 37s
# 283:	learn: 0.5788298	total: 38.7s	remaining: 1m 37s
# 284:	learn: 0.5787062	total: 38.8s	remaining: 1m 37s
# 285:	learn: 0.5784046	total: 38.9s	remaining: 1m 37s
# 286:	learn: 0.5782564	total: 39.1s	remaining: 1m 37s
# 287:	learn: 0.5781406	total: 39.2s	remaining: 1m 36s
# 288:	learn: 0.5778431	total: 39.3s	remaining: 1m 36s
# 289:	learn: 0.5776363	total: 39.5s	remaining: 1m 36s
# 290:	learn: 0.5775204	total: 39.6s	remaining: 1m 36s
# 291:	learn: 0.5772266	total: 39.7s	remaining: 1m 36s
# 292:	learn: 0.5771204	total: 39.9s	remaining: 1m 36s
# 293:	learn: 0.5769433	total: 40s	remaining: 1m 36s
# 294:	learn: 0.5768007	total: 40.1s	remaining: 1m 35s
# 295:	learn: 0.5766859	total: 40.3s	remaining: 1m 35s
# 296:	learn: 0.5764903	total: 40.4s	remaining: 1m 35s
# 297:	learn: 0.5763492	total: 40.6s	remaining: 1m 35s
# 298:	learn: 0.5761699	total: 40.7s	remaining: 1m 35s
# 299:	learn: 0.5759024	total: 40.8s	remaining: 1m 35s
# 300:	learn: 0.5757803	total: 41s	remaining: 1m 35s
# 301:	learn: 0.5756437	total: 41.1s	remaining: 1m 34s
# 302:	learn: 0.5754328	total: 41.2s	remaining: 1m 34s
# 303:	learn: 0.5751218	total: 41.4s	remaining: 1m 34s
# 304:	learn: 0.5749361	total: 41.5s	remaining: 1m 34s
# 305:	learn: 0.5747712	total: 41.6s	remaining: 1m 34s
# 306:	learn: 0.5746423	total: 41.8s	remaining: 1m 34s
# 307:	learn: 0.5745176	total: 41.9s	remaining: 1m 34s
# 308:	learn: 0.5743431	total: 42s	remaining: 1m 34s
# 309:	learn: 0.5741761	total: 42.2s	remaining: 1m 33s
# 310:	learn: 0.5740610	total: 42.3s	remaining: 1m 33s
# 311:	learn: 0.5738656	total: 42.4s	remaining: 1m 33s
# 312:	learn: 0.5737265	total: 42.6s	remaining: 1m 33s
# 313:	learn: 0.5735009	total: 42.7s	remaining: 1m 33s
# 314:	learn: 0.5732351	total: 42.8s	remaining: 1m 33s
# 315:	learn: 0.5730116	total: 43s	remaining: 1m 33s
# 316:	learn: 0.5728709	total: 43.1s	remaining: 1m 32s
# 317:	learn: 0.5727399	total: 43.2s	remaining: 1m 32s
# 318:	learn: 0.5725809	total: 43.4s	remaining: 1m 32s
# 319:	learn: 0.5724685	total: 43.5s	remaining: 1m 32s
# 320:	learn: 0.5722121	total: 43.7s	remaining: 1m 32s
# 321:	learn: 0.5720064	total: 43.8s	remaining: 1m 32s
# 322:	learn: 0.5718144	total: 43.9s	remaining: 1m 32s
# 323:	learn: 0.5716612	total: 44.1s	remaining: 1m 31s
# 324:	learn: 0.5713842	total: 44.2s	remaining: 1m 31s
# 325:	learn: 0.5712183	total: 44.3s	remaining: 1m 31s
# 326:	learn: 0.5710287	total: 44.5s	remaining: 1m 31s
# 327:	learn: 0.5707781	total: 44.6s	remaining: 1m 31s
# 328:	learn: 0.5706088	total: 44.7s	remaining: 1m 31s
# 329:	learn: 0.5703989	total: 44.9s	remaining: 1m 31s
# 330:	learn: 0.5701911	total: 45s	remaining: 1m 30s
# 331:	learn: 0.5699971	total: 45.1s	remaining: 1m 30s
# 332:	learn: 0.5698844	total: 45.3s	remaining: 1m 30s
# 333:	learn: 0.5696915	total: 45.4s	remaining: 1m 30s
# 334:	learn: 0.5695935	total: 45.5s	remaining: 1m 30s
# 335:	learn: 0.5694631	total: 45.7s	remaining: 1m 30s
# 336:	learn: 0.5693125	total: 45.8s	remaining: 1m 30s
# 337:	learn: 0.5691376	total: 46s	remaining: 1m 30s
# 338:	learn: 0.5688618	total: 46.1s	remaining: 1m 29s
# 339:	learn: 0.5686510	total: 46.2s	remaining: 1m 29s
# 340:	learn: 0.5684166	total: 46.4s	remaining: 1m 29s
# 341:	learn: 0.5681450	total: 46.5s	remaining: 1m 29s
# 342:	learn: 0.5677983	total: 46.6s	remaining: 1m 29s
# 343:	learn: 0.5676178	total: 46.8s	remaining: 1m 29s
# 344:	learn: 0.5675117	total: 46.9s	remaining: 1m 29s
# 345:	learn: 0.5673539	total: 47s	remaining: 1m 28s
# 346:	learn: 0.5670976	total: 47.2s	remaining: 1m 28s
# 347:	learn: 0.5669532	total: 47.3s	remaining: 1m 28s
# 348:	learn: 0.5666789	total: 47.4s	remaining: 1m 28s
# 349:	learn: 0.5664519	total: 47.6s	remaining: 1m 28s
# 350:	learn: 0.5662595	total: 47.7s	remaining: 1m 28s
# 351:	learn: 0.5660803	total: 47.9s	remaining: 1m 28s
# 352:	learn: 0.5659483	total: 48s	remaining: 1m 27s
# 353:	learn: 0.5658511	total: 48.1s	remaining: 1m 27s
# 354:	learn: 0.5656286	total: 48.3s	remaining: 1m 27s
# 355:	learn: 0.5655285	total: 48.4s	remaining: 1m 27s
# 356:	learn: 0.5652419	total: 48.5s	remaining: 1m 27s
# 357:	learn: 0.5649560	total: 48.7s	remaining: 1m 27s
# 358:	learn: 0.5647965	total: 48.8s	remaining: 1m 27s
# 359:	learn: 0.5646407	total: 48.9s	remaining: 1m 27s
# 360:	learn: 0.5644684	total: 49.1s	remaining: 1m 26s
# 361:	learn: 0.5643358	total: 49.2s	remaining: 1m 26s
# 362:	learn: 0.5641636	total: 49.3s	remaining: 1m 26s
# 363:	learn: 0.5640307	total: 49.5s	remaining: 1m 26s
# 364:	learn: 0.5637726	total: 49.6s	remaining: 1m 26s
# 365:	learn: 0.5635689	total: 49.8s	remaining: 1m 26s
# 366:	learn: 0.5634277	total: 49.9s	remaining: 1m 26s
# 367:	learn: 0.5632390	total: 50s	remaining: 1m 25s
# 368:	learn: 0.5630879	total: 50.2s	remaining: 1m 25s
# 369:	learn: 0.5629266	total: 50.3s	remaining: 1m 25s
# 370:	learn: 0.5628074	total: 50.4s	remaining: 1m 25s
# 371:	learn: 0.5625949	total: 50.6s	remaining: 1m 25s
# 372:	learn: 0.5623819	total: 50.7s	remaining: 1m 25s
# 373:	learn: 0.5622007	total: 50.8s	remaining: 1m 25s
# 374:	learn: 0.5620665	total: 51s	remaining: 1m 24s
# 375:	learn: 0.5619446	total: 51.1s	remaining: 1m 24s
# 376:	learn: 0.5617680	total: 51.2s	remaining: 1m 24s
# 377:	learn: 0.5616274	total: 51.4s	remaining: 1m 24s
# 378:	learn: 0.5614337	total: 51.5s	remaining: 1m 24s
# 379:	learn: 0.5613165	total: 51.6s	remaining: 1m 24s
# 380:	learn: 0.5611239	total: 51.8s	remaining: 1m 24s
# 381:	learn: 0.5609030	total: 51.9s	remaining: 1m 23s
# 382:	learn: 0.5606757	total: 52.1s	remaining: 1m 23s
# 383:	learn: 0.5605413	total: 52.2s	remaining: 1m 23s
# 384:	learn: 0.5603765	total: 52.3s	remaining: 1m 23s
# 385:	learn: 0.5602472	total: 52.5s	remaining: 1m 23s
# 386:	learn: 0.5600903	total: 52.6s	remaining: 1m 23s
# 387:	learn: 0.5598998	total: 52.7s	remaining: 1m 23s
# 388:	learn: 0.5597433	total: 52.9s	remaining: 1m 23s
# 389:	learn: 0.5595602	total: 53s	remaining: 1m 22s
# 390:	learn: 0.5593820	total: 53.1s	remaining: 1m 22s
# 391:	learn: 0.5592433	total: 53.3s	remaining: 1m 22s
# 392:	learn: 0.5590297	total: 53.4s	remaining: 1m 22s
# 393:	learn: 0.5588580	total: 53.5s	remaining: 1m 22s
# 394:	learn: 0.5587337	total: 53.7s	remaining: 1m 22s
# 395:	learn: 0.5585690	total: 53.8s	remaining: 1m 22s
# 396:	learn: 0.5584130	total: 53.9s	remaining: 1m 21s
# 397:	learn: 0.5581887	total: 54.1s	remaining: 1m 21s
# 398:	learn: 0.5579431	total: 54.2s	remaining: 1m 21s
# 399:	learn: 0.5577591	total: 54.4s	remaining: 1m 21s
# 400:	learn: 0.5576515	total: 54.5s	remaining: 1m 21s
# 401:	learn: 0.5575029	total: 54.6s	remaining: 1m 21s
# 402:	learn: 0.5573372	total: 54.8s	remaining: 1m 21s
# 403:	learn: 0.5572075	total: 54.9s	remaining: 1m 20s
# 404:	learn: 0.5570432	total: 55s	remaining: 1m 20s
# 405:	learn: 0.5567970	total: 55.2s	remaining: 1m 20s
# 406:	learn: 0.5567183	total: 55.3s	remaining: 1m 20s
# 407:	learn: 0.5565591	total: 55.4s	remaining: 1m 20s
# 408:	learn: 0.5564607	total: 55.6s	remaining: 1m 20s
# 409:	learn: 0.5563236	total: 55.7s	remaining: 1m 20s
# 410:	learn: 0.5561356	total: 55.8s	remaining: 1m 20s
# 411:	learn: 0.5559326	total: 56s	remaining: 1m 19s
# 412:	learn: 0.5557868	total: 56.1s	remaining: 1m 19s
# 413:	learn: 0.5557003	total: 56.2s	remaining: 1m 19s
# 414:	learn: 0.5555440	total: 56.4s	remaining: 1m 19s
# 415:	learn: 0.5553000	total: 56.5s	remaining: 1m 19s
# 416:	learn: 0.5551195	total: 56.6s	remaining: 1m 19s
# 417:	learn: 0.5549963	total: 56.8s	remaining: 1m 19s
# 418:	learn: 0.5548162	total: 56.9s	remaining: 1m 18s
# 419:	learn: 0.5546691	total: 57.1s	remaining: 1m 18s
# 420:	learn: 0.5545506	total: 57.2s	remaining: 1m 18s
# 421:	learn: 0.5544189	total: 57.3s	remaining: 1m 18s
# 422:	learn: 0.5542123	total: 57.5s	remaining: 1m 18s
# 423:	learn: 0.5541184	total: 57.6s	remaining: 1m 18s
# 424:	learn: 0.5538938	total: 57.7s	remaining: 1m 18s
# 425:	learn: 0.5537361	total: 57.9s	remaining: 1m 17s
# 426:	learn: 0.5535834	total: 58s	remaining: 1m 17s
# 427:	learn: 0.5533997	total: 58.1s	remaining: 1m 17s
# 428:	learn: 0.5531609	total: 58.3s	remaining: 1m 17s
# 429:	learn: 0.5529772	total: 58.4s	remaining: 1m 17s
# 430:	learn: 0.5528268	total: 58.5s	remaining: 1m 17s
# 431:	learn: 0.5525386	total: 58.7s	remaining: 1m 17s
# 432:	learn: 0.5523568	total: 58.8s	remaining: 1m 17s
# 433:	learn: 0.5522160	total: 58.9s	remaining: 1m 16s
# 434:	learn: 0.5520610	total: 59.1s	remaining: 1m 16s
# 435:	learn: 0.5519190	total: 59.2s	remaining: 1m 16s
# 436:	learn: 0.5516938	total: 59.3s	remaining: 1m 16s
# 437:	learn: 0.5515408	total: 59.5s	remaining: 1m 16s
# 438:	learn: 0.5513681	total: 59.6s	remaining: 1m 16s
# 439:	learn: 0.5511797	total: 59.8s	remaining: 1m 16s
# 440:	learn: 0.5508475	total: 59.9s	remaining: 1m 15s
# 441:	learn: 0.5505792	total: 1m	remaining: 1m 15s
# 442:	learn: 0.5505413	total: 1m	remaining: 1m 15s
# 443:	learn: 0.5504171	total: 1m	remaining: 1m 15s
# 444:	learn: 0.5501599	total: 1m	remaining: 1m 15s
# 445:	learn: 0.5500136	total: 1m	remaining: 1m 15s
# 446:	learn: 0.5498860	total: 1m	remaining: 1m 15s
# 447:	learn: 0.5497084	total: 1m	remaining: 1m 14s
# 448:	learn: 0.5495675	total: 1m	remaining: 1m 14s
# 449:	learn: 0.5494626	total: 1m 1s	remaining: 1m 14s
# 450:	learn: 0.5493521	total: 1m 1s	remaining: 1m 14s
# 451:	learn: 0.5492467	total: 1m 1s	remaining: 1m 14s
# 452:	learn: 0.5490098	total: 1m 1s	remaining: 1m 14s
# 453:	learn: 0.5488538	total: 1m 1s	remaining: 1m 14s
# 454:	learn: 0.5487439	total: 1m 1s	remaining: 1m 13s
# 455:	learn: 0.5486280	total: 1m 1s	remaining: 1m 13s
# 456:	learn: 0.5484801	total: 1m 2s	remaining: 1m 13s
# 457:	learn: 0.5483893	total: 1m 2s	remaining: 1m 13s
# 458:	learn: 0.5482117	total: 1m 2s	remaining: 1m 13s
# 459:	learn: 0.5480351	total: 1m 2s	remaining: 1m 13s
# 460:	learn: 0.5478609	total: 1m 2s	remaining: 1m 13s
# 461:	learn: 0.5477681	total: 1m 2s	remaining: 1m 13s
# 462:	learn: 0.5476152	total: 1m 2s	remaining: 1m 12s
# 463:	learn: 0.5472450	total: 1m 2s	remaining: 1m 12s
# 464:	learn: 0.5469731	total: 1m 3s	remaining: 1m 12s
# 465:	learn: 0.5468192	total: 1m 3s	remaining: 1m 12s
# 466:	learn: 0.5466770	total: 1m 3s	remaining: 1m 12s
# 467:	learn: 0.5465097	total: 1m 3s	remaining: 1m 12s
# 468:	learn: 0.5463420	total: 1m 3s	remaining: 1m 12s
# 469:	learn: 0.5461063	total: 1m 3s	remaining: 1m 11s
# 470:	learn: 0.5459659	total: 1m 3s	remaining: 1m 11s
# 471:	learn: 0.5458817	total: 1m 4s	remaining: 1m 11s
# 472:	learn: 0.5456867	total: 1m 4s	remaining: 1m 11s
# 473:	learn: 0.5455245	total: 1m 4s	remaining: 1m 11s
# 474:	learn: 0.5454163	total: 1m 4s	remaining: 1m 11s
# 475:	learn: 0.5451246	total: 1m 4s	remaining: 1m 11s
# 476:	learn: 0.5450544	total: 1m 4s	remaining: 1m 10s
# 477:	learn: 0.5449232	total: 1m 4s	remaining: 1m 10s
# 478:	learn: 0.5447566	total: 1m 5s	remaining: 1m 10s
# 479:	learn: 0.5446509	total: 1m 5s	remaining: 1m 10s
# 480:	learn: 0.5445365	total: 1m 5s	remaining: 1m 10s
# 481:	learn: 0.5444275	total: 1m 5s	remaining: 1m 10s
# 482:	learn: 0.5440938	total: 1m 5s	remaining: 1m 10s
# 483:	learn: 0.5439931	total: 1m 5s	remaining: 1m 10s
# 484:	learn: 0.5438838	total: 1m 5s	remaining: 1m 9s
# 485:	learn: 0.5437348	total: 1m 5s	remaining: 1m 9s
# 486:	learn: 0.5435705	total: 1m 6s	remaining: 1m 9s
# 487:	learn: 0.5434377	total: 1m 6s	remaining: 1m 9s
# 488:	learn: 0.5432771	total: 1m 6s	remaining: 1m 9s
# 489:	learn: 0.5431111	total: 1m 6s	remaining: 1m 9s
# 490:	learn: 0.5429929	total: 1m 6s	remaining: 1m 9s
# 491:	learn: 0.5428188	total: 1m 6s	remaining: 1m 8s
# 492:	learn: 0.5427087	total: 1m 6s	remaining: 1m 8s
# 493:	learn: 0.5425657	total: 1m 7s	remaining: 1m 8s
# 494:	learn: 0.5423903	total: 1m 7s	remaining: 1m 8s
# 495:	learn: 0.5421566	total: 1m 7s	remaining: 1m 8s
# 496:	learn: 0.5420310	total: 1m 7s	remaining: 1m 8s
# 497:	learn: 0.5418371	total: 1m 7s	remaining: 1m 8s
# 498:	learn: 0.5417042	total: 1m 7s	remaining: 1m 8s
# 499:	learn: 0.5416007	total: 1m 7s	remaining: 1m 7s
# 500:	learn: 0.5414210	total: 1m 7s	remaining: 1m 7s
# 501:	learn: 0.5411531	total: 1m 8s	remaining: 1m 7s
# 502:	learn: 0.5410245	total: 1m 8s	remaining: 1m 7s
# 503:	learn: 0.5408387	total: 1m 8s	remaining: 1m 7s
# 504:	learn: 0.5406972	total: 1m 8s	remaining: 1m 7s
# 505:	learn: 0.5405255	total: 1m 8s	remaining: 1m 7s
# 506:	learn: 0.5404039	total: 1m 8s	remaining: 1m 6s
# 507:	learn: 0.5402296	total: 1m 8s	remaining: 1m 6s
# 508:	learn: 0.5400712	total: 1m 9s	remaining: 1m 6s
# 509:	learn: 0.5398986	total: 1m 9s	remaining: 1m 6s
# 510:	learn: 0.5397527	total: 1m 9s	remaining: 1m 6s
# 511:	learn: 0.5395353	total: 1m 9s	remaining: 1m 6s
# 512:	learn: 0.5394585	total: 1m 9s	remaining: 1m 6s
# 513:	learn: 0.5393491	total: 1m 9s	remaining: 1m 6s
# 514:	learn: 0.5392156	total: 1m 10s	remaining: 1m 6s
# 515:	learn: 0.5390739	total: 1m 10s	remaining: 1m 5s
# 516:	learn: 0.5389693	total: 1m 10s	remaining: 1m 5s
# 517:	learn: 0.5387935	total: 1m 10s	remaining: 1m 5s
# 518:	learn: 0.5386991	total: 1m 10s	remaining: 1m 5s
# 519:	learn: 0.5385779	total: 1m 10s	remaining: 1m 5s
# 520:	learn: 0.5384402	total: 1m 10s	remaining: 1m 5s
# 521:	learn: 0.5382563	total: 1m 11s	remaining: 1m 5s
# 522:	learn: 0.5380752	total: 1m 11s	remaining: 1m 4s
# 523:	learn: 0.5379003	total: 1m 11s	remaining: 1m 4s
# 524:	learn: 0.5377217	total: 1m 11s	remaining: 1m 4s
# 525:	learn: 0.5376434	total: 1m 11s	remaining: 1m 4s
# 526:	learn: 0.5374331	total: 1m 11s	remaining: 1m 4s
# 527:	learn: 0.5372650	total: 1m 11s	remaining: 1m 4s
# 528:	learn: 0.5371684	total: 1m 12s	remaining: 1m 4s
# 529:	learn: 0.5369999	total: 1m 12s	remaining: 1m 3s
# 530:	learn: 0.5368544	total: 1m 12s	remaining: 1m 3s
# 531:	learn: 0.5366800	total: 1m 12s	remaining: 1m 3s
# 532:	learn: 0.5365137	total: 1m 12s	remaining: 1m 3s
# 533:	learn: 0.5363073	total: 1m 12s	remaining: 1m 3s
# 534:	learn: 0.5362145	total: 1m 12s	remaining: 1m 3s
# 535:	learn: 0.5360737	total: 1m 12s	remaining: 1m 3s
# 536:	learn: 0.5359697	total: 1m 13s	remaining: 1m 3s
# 537:	learn: 0.5358883	total: 1m 13s	remaining: 1m 2s
# 538:	learn: 0.5356970	total: 1m 13s	remaining: 1m 2s
# 539:	learn: 0.5356022	total: 1m 13s	remaining: 1m 2s
# 540:	learn: 0.5355146	total: 1m 13s	remaining: 1m 2s
# 541:	learn: 0.5353657	total: 1m 13s	remaining: 1m 2s
# 542:	learn: 0.5351973	total: 1m 13s	remaining: 1m 2s
# 543:	learn: 0.5350356	total: 1m 14s	remaining: 1m 2s
# 544:	learn: 0.5349469	total: 1m 14s	remaining: 1m 1s
# 545:	learn: 0.5347388	total: 1m 14s	remaining: 1m 1s
# 546:	learn: 0.5346605	total: 1m 14s	remaining: 1m 1s
# 547:	learn: 0.5345737	total: 1m 14s	remaining: 1m 1s
# 548:	learn: 0.5344634	total: 1m 14s	remaining: 1m 1s
# 549:	learn: 0.5343386	total: 1m 14s	remaining: 1m 1s
# 550:	learn: 0.5342020	total: 1m 15s	remaining: 1m 1s
# 551:	learn: 0.5340688	total: 1m 15s	remaining: 1m
# 552:	learn: 0.5338133	total: 1m 15s	remaining: 1m
# 553:	learn: 0.5337041	total: 1m 15s	remaining: 1m
# 554:	learn: 0.5335633	total: 1m 15s	remaining: 1m
# 555:	learn: 0.5334688	total: 1m 15s	remaining: 1m
# 556:	learn: 0.5332806	total: 1m 15s	remaining: 1m
# 557:	learn: 0.5331863	total: 1m 15s	remaining: 1m
# 558:	learn: 0.5330343	total: 1m 16s	remaining: 1m
# 559:	learn: 0.5329283	total: 1m 16s	remaining: 59.9s
# 560:	learn: 0.5328382	total: 1m 16s	remaining: 59.8s
# 561:	learn: 0.5326914	total: 1m 16s	remaining: 59.6s
# 562:	learn: 0.5326122	total: 1m 16s	remaining: 59.5s
# 563:	learn: 0.5325125	total: 1m 16s	remaining: 59.3s
# 564:	learn: 0.5323688	total: 1m 16s	remaining: 59.2s
# 565:	learn: 0.5321981	total: 1m 17s	remaining: 59.1s
# 566:	learn: 0.5321246	total: 1m 17s	remaining: 58.9s
# 567:	learn: 0.5320332	total: 1m 17s	remaining: 58.8s
# 568:	learn: 0.5319277	total: 1m 17s	remaining: 58.7s
# 569:	learn: 0.5317971	total: 1m 17s	remaining: 58.5s
# 570:	learn: 0.5316324	total: 1m 17s	remaining: 58.4s
# 571:	learn: 0.5314839	total: 1m 17s	remaining: 58.2s
# 572:	learn: 0.5314001	total: 1m 17s	remaining: 58.1s
# 573:	learn: 0.5312507	total: 1m 18s	remaining: 58s
# 574:	learn: 0.5310957	total: 1m 18s	remaining: 57.8s
# 575:	learn: 0.5309356	total: 1m 18s	remaining: 57.7s
# 576:	learn: 0.5308153	total: 1m 18s	remaining: 57.6s
# 577:	learn: 0.5306632	total: 1m 18s	remaining: 57.4s
# 578:	learn: 0.5305519	total: 1m 18s	remaining: 57.3s
# 579:	learn: 0.5303527	total: 1m 18s	remaining: 57.2s
# 580:	learn: 0.5301867	total: 1m 19s	remaining: 57s
# 581:	learn: 0.5301142	total: 1m 19s	remaining: 56.9s
# 582:	learn: 0.5300366	total: 1m 19s	remaining: 56.7s
# 583:	learn: 0.5298440	total: 1m 19s	remaining: 56.6s
# 584:	learn: 0.5297344	total: 1m 19s	remaining: 56.5s
# 585:	learn: 0.5296557	total: 1m 19s	remaining: 56.3s
# 586:	learn: 0.5295593	total: 1m 19s	remaining: 56.2s
# 587:	learn: 0.5294913	total: 1m 20s	remaining: 56.1s
# 588:	learn: 0.5293849	total: 1m 20s	remaining: 55.9s
# 589:	learn: 0.5292371	total: 1m 20s	remaining: 55.8s
# 590:	learn: 0.5291371	total: 1m 20s	remaining: 55.6s
# 591:	learn: 0.5290249	total: 1m 20s	remaining: 55.5s
# 592:	learn: 0.5289342	total: 1m 20s	remaining: 55.4s
# 593:	learn: 0.5288069	total: 1m 20s	remaining: 55.2s
# 594:	learn: 0.5286847	total: 1m 20s	remaining: 55.1s
# 595:	learn: 0.5286146	total: 1m 21s	remaining: 55s
# 596:	learn: 0.5284547	total: 1m 21s	remaining: 54.8s
# 597:	learn: 0.5283826	total: 1m 21s	remaining: 54.7s
# 598:	learn: 0.5282407	total: 1m 21s	remaining: 54.6s
# 599:	learn: 0.5281465	total: 1m 21s	remaining: 54.4s
# 600:	learn: 0.5279923	total: 1m 21s	remaining: 54.3s
# 601:	learn: 0.5279014	total: 1m 21s	remaining: 54.1s
# 602:	learn: 0.5276746	total: 1m 22s	remaining: 54s
# 603:	learn: 0.5275571	total: 1m 22s	remaining: 53.9s
# 604:	learn: 0.5274567	total: 1m 22s	remaining: 53.7s
# 605:	learn: 0.5273326	total: 1m 22s	remaining: 53.6s
# 606:	learn: 0.5272126	total: 1m 22s	remaining: 53.5s
# 607:	learn: 0.5270614	total: 1m 22s	remaining: 53.3s
# 608:	learn: 0.5269595	total: 1m 22s	remaining: 53.2s
# 609:	learn: 0.5268743	total: 1m 22s	remaining: 53.1s
# 610:	learn: 0.5267125	total: 1m 23s	remaining: 52.9s
# 611:	learn: 0.5266047	total: 1m 23s	remaining: 52.8s
# 612:	learn: 0.5264450	total: 1m 23s	remaining: 52.6s
# 613:	learn: 0.5262776	total: 1m 23s	remaining: 52.5s
# 614:	learn: 0.5260925	total: 1m 23s	remaining: 52.4s
# 615:	learn: 0.5260010	total: 1m 23s	remaining: 52.2s
# 616:	learn: 0.5259152	total: 1m 23s	remaining: 52.1s
# 617:	learn: 0.5258098	total: 1m 24s	remaining: 52s
# 618:	learn: 0.5256896	total: 1m 24s	remaining: 51.8s
# 619:	learn: 0.5255404	total: 1m 24s	remaining: 51.7s
# 620:	learn: 0.5253837	total: 1m 24s	remaining: 51.6s
# 621:	learn: 0.5253174	total: 1m 24s	remaining: 51.4s
# 622:	learn: 0.5252244	total: 1m 24s	remaining: 51.3s
# 623:	learn: 0.5251170	total: 1m 24s	remaining: 51.1s
# 624:	learn: 0.5250018	total: 1m 25s	remaining: 51s
# 625:	learn: 0.5248524	total: 1m 25s	remaining: 50.9s
# 626:	learn: 0.5246956	total: 1m 25s	remaining: 50.7s
# 627:	learn: 0.5245539	total: 1m 25s	remaining: 50.6s
# 628:	learn: 0.5244707	total: 1m 25s	remaining: 50.5s
# 629:	learn: 0.5243710	total: 1m 25s	remaining: 50.3s
# 630:	learn: 0.5243126	total: 1m 25s	remaining: 50.2s
# 631:	learn: 0.5241437	total: 1m 25s	remaining: 50.1s
# 632:	learn: 0.5238658	total: 1m 26s	remaining: 49.9s
# 633:	learn: 0.5237742	total: 1m 26s	remaining: 49.8s
# 634:	learn: 0.5236162	total: 1m 26s	remaining: 49.6s
# 635:	learn: 0.5235397	total: 1m 26s	remaining: 49.5s
# 636:	learn: 0.5234067	total: 1m 26s	remaining: 49.4s
# 637:	learn: 0.5233543	total: 1m 26s	remaining: 49.2s
# 638:	learn: 0.5232770	total: 1m 26s	remaining: 49.1s
# 639:	learn: 0.5231677	total: 1m 27s	remaining: 49s
# 640:	learn: 0.5229748	total: 1m 27s	remaining: 48.8s
# 641:	learn: 0.5228332	total: 1m 27s	remaining: 48.7s
# 642:	learn: 0.5227135	total: 1m 27s	remaining: 48.6s
# 643:	learn: 0.5226115	total: 1m 27s	remaining: 48.4s
# 644:	learn: 0.5224818	total: 1m 27s	remaining: 48.3s
# 645:	learn: 0.5223714	total: 1m 27s	remaining: 48.1s
# 646:	learn: 0.5222741	total: 1m 27s	remaining: 48s
# 647:	learn: 0.5221606	total: 1m 28s	remaining: 47.9s
# 648:	learn: 0.5220055	total: 1m 28s	remaining: 47.7s
# 649:	learn: 0.5219245	total: 1m 28s	remaining: 47.6s
# 650:	learn: 0.5218628	total: 1m 28s	remaining: 47.5s
# 651:	learn: 0.5218002	total: 1m 28s	remaining: 47.3s
# 652:	learn: 0.5216650	total: 1m 28s	remaining: 47.2s
# 653:	learn: 0.5215027	total: 1m 28s	remaining: 47.1s
# 654:	learn: 0.5213846	total: 1m 29s	remaining: 46.9s
# 655:	learn: 0.5211649	total: 1m 29s	remaining: 46.8s
# 656:	learn: 0.5210670	total: 1m 29s	remaining: 46.6s
# 657:	learn: 0.5209222	total: 1m 29s	remaining: 46.5s
# 658:	learn: 0.5207935	total: 1m 29s	remaining: 46.4s
# 659:	learn: 0.5207220	total: 1m 29s	remaining: 46.2s
# 660:	learn: 0.5205794	total: 1m 29s	remaining: 46.1s
# 661:	learn: 0.5204016	total: 1m 30s	remaining: 46s
# 662:	learn: 0.5202611	total: 1m 30s	remaining: 45.8s
# 663:	learn: 0.5200715	total: 1m 30s	remaining: 45.7s
# 664:	learn: 0.5199634	total: 1m 30s	remaining: 45.6s
# 665:	learn: 0.5198389	total: 1m 30s	remaining: 45.4s
# 666:	learn: 0.5197421	total: 1m 30s	remaining: 45.3s
# 667:	learn: 0.5196513	total: 1m 30s	remaining: 45.1s
# 668:	learn: 0.5195555	total: 1m 30s	remaining: 45s
# 669:	learn: 0.5194708	total: 1m 31s	remaining: 44.9s
# 670:	learn: 0.5193479	total: 1m 31s	remaining: 44.7s
# 671:	learn: 0.5192891	total: 1m 31s	remaining: 44.6s
# 672:	learn: 0.5192126	total: 1m 31s	remaining: 44.5s
# 673:	learn: 0.5190933	total: 1m 31s	remaining: 44.3s
# 674:	learn: 0.5189764	total: 1m 31s	remaining: 44.2s
# 675:	learn: 0.5187753	total: 1m 31s	remaining: 44.1s
# 676:	learn: 0.5186900	total: 1m 32s	remaining: 43.9s
# 677:	learn: 0.5185962	total: 1m 32s	remaining: 43.8s
# 678:	learn: 0.5184803	total: 1m 32s	remaining: 43.6s
# 679:	learn: 0.5183928	total: 1m 32s	remaining: 43.5s
# 680:	learn: 0.5182670	total: 1m 32s	remaining: 43.4s
# 681:	learn: 0.5181474	total: 1m 32s	remaining: 43.2s
# 682:	learn: 0.5180577	total: 1m 32s	remaining: 43.1s
# 683:	learn: 0.5179730	total: 1m 32s	remaining: 43s
# 684:	learn: 0.5178662	total: 1m 33s	remaining: 42.8s
# 685:	learn: 0.5177230	total: 1m 33s	remaining: 42.7s
# 686:	learn: 0.5176139	total: 1m 33s	remaining: 42.5s
# 687:	learn: 0.5174899	total: 1m 33s	remaining: 42.4s
# 688:	learn: 0.5173786	total: 1m 33s	remaining: 42.3s
# 689:	learn: 0.5172711	total: 1m 33s	remaining: 42.1s
# 690:	learn: 0.5171208	total: 1m 33s	remaining: 42s
# 691:	learn: 0.5170205	total: 1m 34s	remaining: 41.9s
# 692:	learn: 0.5168687	total: 1m 34s	remaining: 41.7s
# 693:	learn: 0.5167661	total: 1m 34s	remaining: 41.6s
# 694:	learn: 0.5166606	total: 1m 34s	remaining: 41.5s
# 695:	learn: 0.5165160	total: 1m 34s	remaining: 41.3s
# 696:	learn: 0.5164434	total: 1m 34s	remaining: 41.2s
# 697:	learn: 0.5162845	total: 1m 34s	remaining: 41.1s
# 698:	learn: 0.5161883	total: 1m 35s	remaining: 40.9s
# 699:	learn: 0.5161258	total: 1m 35s	remaining: 40.8s
# 700:	learn: 0.5159336	total: 1m 35s	remaining: 40.6s
# 701:	learn: 0.5158746	total: 1m 35s	remaining: 40.5s
# 702:	learn: 0.5157135	total: 1m 35s	remaining: 40.4s
# 703:	learn: 0.5156294	total: 1m 35s	remaining: 40.2s
# 704:	learn: 0.5154812	total: 1m 35s	remaining: 40.1s
# 705:	learn: 0.5153835	total: 1m 35s	remaining: 40s
# 706:	learn: 0.5152966	total: 1m 36s	remaining: 39.8s
# 707:	learn: 0.5151952	total: 1m 36s	remaining: 39.7s
# 708:	learn: 0.5151162	total: 1m 36s	remaining: 39.6s
# 709:	learn: 0.5150045	total: 1m 36s	remaining: 39.4s
# 710:	learn: 0.5149199	total: 1m 36s	remaining: 39.3s
# 711:	learn: 0.5147589	total: 1m 36s	remaining: 39.1s
# 712:	learn: 0.5146197	total: 1m 36s	remaining: 39s
# 713:	learn: 0.5145163	total: 1m 37s	remaining: 38.9s
# 714:	learn: 0.5143790	total: 1m 37s	remaining: 38.7s
# 715:	learn: 0.5142530	total: 1m 37s	remaining: 38.6s
# 716:	learn: 0.5141265	total: 1m 37s	remaining: 38.5s
# 717:	learn: 0.5139964	total: 1m 37s	remaining: 38.3s
# 718:	learn: 0.5139300	total: 1m 37s	remaining: 38.2s
# 719:	learn: 0.5137954	total: 1m 37s	remaining: 38.1s
# 720:	learn: 0.5136328	total: 1m 37s	remaining: 37.9s
# 721:	learn: 0.5135596	total: 1m 38s	remaining: 37.8s
# 722:	learn: 0.5134861	total: 1m 38s	remaining: 37.6s
# 723:	learn: 0.5133353	total: 1m 38s	remaining: 37.5s
# 724:	learn: 0.5132657	total: 1m 38s	remaining: 37.4s
# 725:	learn: 0.5130926	total: 1m 38s	remaining: 37.2s
# 726:	learn: 0.5129957	total: 1m 38s	remaining: 37.1s
# 727:	learn: 0.5128763	total: 1m 38s	remaining: 37s
# 728:	learn: 0.5127453	total: 1m 39s	remaining: 36.8s
# 729:	learn: 0.5126376	total: 1m 39s	remaining: 36.7s
# 730:	learn: 0.5124668	total: 1m 39s	remaining: 36.6s
# 731:	learn: 0.5123408	total: 1m 39s	remaining: 36.4s
# 732:	learn: 0.5122115	total: 1m 39s	remaining: 36.3s
# 733:	learn: 0.5120676	total: 1m 39s	remaining: 36.1s
# 734:	learn: 0.5118993	total: 1m 39s	remaining: 36s
# 735:	learn: 0.5117974	total: 1m 40s	remaining: 35.9s
# 736:	learn: 0.5116013	total: 1m 40s	remaining: 35.7s
# 737:	learn: 0.5114455	total: 1m 40s	remaining: 35.6s
# 738:	learn: 0.5113035	total: 1m 40s	remaining: 35.5s
# 739:	learn: 0.5111811	total: 1m 40s	remaining: 35.3s
# 740:	learn: 0.5110911	total: 1m 40s	remaining: 35.2s
# 741:	learn: 0.5110228	total: 1m 40s	remaining: 35.1s
# 742:	learn: 0.5108516	total: 1m 40s	remaining: 34.9s
# 743:	learn: 0.5107803	total: 1m 41s	remaining: 34.8s
# 744:	learn: 0.5107060	total: 1m 41s	remaining: 34.6s
# 745:	learn: 0.5106181	total: 1m 41s	remaining: 34.5s
# 746:	learn: 0.5103902	total: 1m 41s	remaining: 34.4s
# 747:	learn: 0.5103396	total: 1m 41s	remaining: 34.2s
# 748:	learn: 0.5102146	total: 1m 41s	remaining: 34.1s
# 749:	learn: 0.5100119	total: 1m 41s	remaining: 34s
# 750:	learn: 0.5098325	total: 1m 42s	remaining: 33.8s
# 751:	learn: 0.5097119	total: 1m 42s	remaining: 33.7s
# 752:	learn: 0.5096074	total: 1m 42s	remaining: 33.6s
# 753:	learn: 0.5095290	total: 1m 42s	remaining: 33.4s
# 754:	learn: 0.5094151	total: 1m 42s	remaining: 33.3s
# 755:	learn: 0.5093555	total: 1m 42s	remaining: 33.2s
# 756:	learn: 0.5092185	total: 1m 42s	remaining: 33s
# 757:	learn: 0.5089809	total: 1m 42s	remaining: 32.9s
# 758:	learn: 0.5088710	total: 1m 43s	remaining: 32.7s
# 759:	learn: 0.5087718	total: 1m 43s	remaining: 32.6s
# 760:	learn: 0.5086258	total: 1m 43s	remaining: 32.5s
# 761:	learn: 0.5085466	total: 1m 43s	remaining: 32.3s
# 762:	learn: 0.5084577	total: 1m 43s	remaining: 32.2s
# 763:	learn: 0.5083896	total: 1m 43s	remaining: 32.1s
# 764:	learn: 0.5083025	total: 1m 43s	remaining: 31.9s
# 765:	learn: 0.5082033	total: 1m 44s	remaining: 31.8s
# 766:	learn: 0.5080821	total: 1m 44s	remaining: 31.7s
# 767:	learn: 0.5079945	total: 1m 44s	remaining: 31.5s
# 768:	learn: 0.5078616	total: 1m 44s	remaining: 31.4s
# 769:	learn: 0.5077265	total: 1m 44s	remaining: 31.2s
# 770:	learn: 0.5075749	total: 1m 44s	remaining: 31.1s
# 771:	learn: 0.5074855	total: 1m 44s	remaining: 31s
# 772:	learn: 0.5073585	total: 1m 45s	remaining: 30.8s
# 773:	learn: 0.5072227	total: 1m 45s	remaining: 30.7s
# 774:	learn: 0.5071423	total: 1m 45s	remaining: 30.6s
# 775:	learn: 0.5069709	total: 1m 45s	remaining: 30.4s
# 776:	learn: 0.5068825	total: 1m 45s	remaining: 30.3s
# 777:	learn: 0.5068164	total: 1m 45s	remaining: 30.2s
# 778:	learn: 0.5067163	total: 1m 45s	remaining: 30s
# 779:	learn: 0.5066379	total: 1m 45s	remaining: 29.9s
# 780:	learn: 0.5065535	total: 1m 46s	remaining: 29.8s
# 781:	learn: 0.5064259	total: 1m 46s	remaining: 29.6s
# 782:	learn: 0.5063080	total: 1m 46s	remaining: 29.5s
# 783:	learn: 0.5062258	total: 1m 46s	remaining: 29.3s
# 784:	learn: 0.5061297	total: 1m 46s	remaining: 29.2s
# 785:	learn: 0.5060143	total: 1m 46s	remaining: 29.1s
# 786:	learn: 0.5059026	total: 1m 46s	remaining: 28.9s
# 787:	learn: 0.5057575	total: 1m 47s	remaining: 28.8s
# 788:	learn: 0.5056962	total: 1m 47s	remaining: 28.7s
# 789:	learn: 0.5056005	total: 1m 47s	remaining: 28.5s
# 790:	learn: 0.5054790	total: 1m 47s	remaining: 28.4s
# 791:	learn: 0.5054045	total: 1m 47s	remaining: 28.3s
# 792:	learn: 0.5052670	total: 1m 47s	remaining: 28.1s
# 793:	learn: 0.5051772	total: 1m 47s	remaining: 28s
# 794:	learn: 0.5051334	total: 1m 47s	remaining: 27.8s
# 795:	learn: 0.5050022	total: 1m 48s	remaining: 27.7s
# 796:	learn: 0.5049203	total: 1m 48s	remaining: 27.6s
# 797:	learn: 0.5047908	total: 1m 48s	remaining: 27.4s
# 798:	learn: 0.5046827	total: 1m 48s	remaining: 27.3s
# 799:	learn: 0.5045561	total: 1m 48s	remaining: 27.2s
# 800:	learn: 0.5044516	total: 1m 48s	remaining: 27s
# 801:	learn: 0.5043135	total: 1m 48s	remaining: 26.9s
# 802:	learn: 0.5041823	total: 1m 49s	remaining: 26.8s
# 803:	learn: 0.5040609	total: 1m 49s	remaining: 26.6s
# 804:	learn: 0.5039459	total: 1m 49s	remaining: 26.5s
# 805:	learn: 0.5038983	total: 1m 49s	remaining: 26.3s
# 806:	learn: 0.5038272	total: 1m 49s	remaining: 26.2s
# 807:	learn: 0.5036711	total: 1m 49s	remaining: 26.1s
# 808:	learn: 0.5035737	total: 1m 49s	remaining: 25.9s
# 809:	learn: 0.5034992	total: 1m 50s	remaining: 25.8s
# 810:	learn: 0.5034287	total: 1m 50s	remaining: 25.7s
# 811:	learn: 0.5033351	total: 1m 50s	remaining: 25.5s
# 812:	learn: 0.5031728	total: 1m 50s	remaining: 25.4s
# 813:	learn: 0.5030287	total: 1m 50s	remaining: 25.3s
# 814:	learn: 0.5029297	total: 1m 50s	remaining: 25.1s
# 815:	learn: 0.5027560	total: 1m 50s	remaining: 25s
# 816:	learn: 0.5026788	total: 1m 50s	remaining: 24.9s
# 817:	learn: 0.5025567	total: 1m 51s	remaining: 24.7s
# 818:	learn: 0.5024466	total: 1m 51s	remaining: 24.6s
# 819:	learn: 0.5023843	total: 1m 51s	remaining: 24.4s
# 820:	learn: 0.5022237	total: 1m 51s	remaining: 24.3s
# 821:	learn: 0.5021065	total: 1m 51s	remaining: 24.2s
# 822:	learn: 0.5020000	total: 1m 51s	remaining: 24s
# 823:	learn: 0.5019188	total: 1m 51s	remaining: 23.9s
# 824:	learn: 0.5018452	total: 1m 52s	remaining: 23.8s
# 825:	learn: 0.5017502	total: 1m 52s	remaining: 23.6s
# 826:	learn: 0.5015849	total: 1m 52s	remaining: 23.5s
# 827:	learn: 0.5014934	total: 1m 52s	remaining: 23.4s
# 828:	learn: 0.5014014	total: 1m 52s	remaining: 23.2s
# 829:	learn: 0.5012800	total: 1m 52s	remaining: 23.1s
# 830:	learn: 0.5012358	total: 1m 52s	remaining: 22.9s
# 831:	learn: 0.5011374	total: 1m 52s	remaining: 22.8s
# 832:	learn: 0.5010388	total: 1m 53s	remaining: 22.7s
# 833:	learn: 0.5009730	total: 1m 53s	remaining: 22.5s
# 834:	learn: 0.5008694	total: 1m 53s	remaining: 22.4s
# 835:	learn: 0.5007658	total: 1m 53s	remaining: 22.3s
# 836:	learn: 0.5006798	total: 1m 53s	remaining: 22.1s
# 837:	learn: 0.5005655	total: 1m 53s	remaining: 22s
# 838:	learn: 0.5004634	total: 1m 53s	remaining: 21.9s
# 839:	learn: 0.5003849	total: 1m 54s	remaining: 21.7s
# 840:	learn: 0.5002635	total: 1m 54s	remaining: 21.6s
# 841:	learn: 0.5001771	total: 1m 54s	remaining: 21.5s
# 842:	learn: 0.5000507	total: 1m 54s	remaining: 21.3s
# 843:	learn: 0.4999394	total: 1m 54s	remaining: 21.2s
# 844:	learn: 0.4998170	total: 1m 54s	remaining: 21s
# 845:	learn: 0.4997073	total: 1m 54s	remaining: 20.9s
# 846:	learn: 0.4996021	total: 1m 55s	remaining: 20.8s
# 847:	learn: 0.4994884	total: 1m 55s	remaining: 20.6s
# 848:	learn: 0.4994064	total: 1m 55s	remaining: 20.5s
# 849:	learn: 0.4992991	total: 1m 55s	remaining: 20.4s
# 850:	learn: 0.4992274	total: 1m 55s	remaining: 20.2s
# 851:	learn: 0.4991383	total: 1m 55s	remaining: 20.1s
# 852:	learn: 0.4990207	total: 1m 55s	remaining: 20s
# 853:	learn: 0.4988867	total: 1m 55s	remaining: 19.8s
# 854:	learn: 0.4987849	total: 1m 56s	remaining: 19.7s
# 855:	learn: 0.4985655	total: 1m 56s	remaining: 19.6s
# 856:	learn: 0.4984631	total: 1m 56s	remaining: 19.4s
# 857:	learn: 0.4983616	total: 1m 56s	remaining: 19.3s
# 858:	learn: 0.4982649	total: 1m 56s	remaining: 19.1s
# 859:	learn: 0.4981979	total: 1m 56s	remaining: 19s
# 860:	learn: 0.4980976	total: 1m 56s	remaining: 18.9s
# 861:	learn: 0.4980404	total: 1m 57s	remaining: 18.7s
# 862:	learn: 0.4979584	total: 1m 57s	remaining: 18.6s
# 863:	learn: 0.4977717	total: 1m 57s	remaining: 18.5s
# 864:	learn: 0.4976802	total: 1m 57s	remaining: 18.3s
# 865:	learn: 0.4975829	total: 1m 57s	remaining: 18.2s
# 866:	learn: 0.4973645	total: 1m 57s	remaining: 18.1s
# 867:	learn: 0.4972694	total: 1m 57s	remaining: 17.9s
# 868:	learn: 0.4972033	total: 1m 57s	remaining: 17.8s
# 869:	learn: 0.4970995	total: 1m 58s	remaining: 17.6s
# 870:	learn: 0.4970412	total: 1m 58s	remaining: 17.5s
# 871:	learn: 0.4969332	total: 1m 58s	remaining: 17.4s
# 872:	learn: 0.4968709	total: 1m 58s	remaining: 17.2s
# 873:	learn: 0.4967811	total: 1m 58s	remaining: 17.1s
# 874:	learn: 0.4967105	total: 1m 58s	remaining: 17s
# 875:	learn: 0.4966249	total: 1m 58s	remaining: 16.8s
# 876:	learn: 0.4965286	total: 1m 59s	remaining: 16.7s
# 877:	learn: 0.4964097	total: 1m 59s	remaining: 16.6s
# 878:	learn: 0.4962499	total: 1m 59s	remaining: 16.4s
# 879:	learn: 0.4961451	total: 1m 59s	remaining: 16.3s
# 880:	learn: 0.4959986	total: 1m 59s	remaining: 16.2s
# 881:	learn: 0.4958740	total: 1m 59s	remaining: 16s
# 882:	learn: 0.4958024	total: 1m 59s	remaining: 15.9s
# 883:	learn: 0.4957283	total: 2m	remaining: 15.7s
# 884:	learn: 0.4956352	total: 2m	remaining: 15.6s
# 885:	learn: 0.4955440	total: 2m	remaining: 15.5s
# 886:	learn: 0.4954595	total: 2m	remaining: 15.3s
# 887:	learn: 0.4953286	total: 2m	remaining: 15.2s
# 888:	learn: 0.4952377	total: 2m	remaining: 15.1s
# 889:	learn: 0.4951455	total: 2m	remaining: 14.9s
# 890:	learn: 0.4950590	total: 2m	remaining: 14.8s
# 891:	learn: 0.4949577	total: 2m 1s	remaining: 14.7s
# 892:	learn: 0.4948352	total: 2m 1s	remaining: 14.5s
# 893:	learn: 0.4947675	total: 2m 1s	remaining: 14.4s
# 894:	learn: 0.4946839	total: 2m 1s	remaining: 14.3s
# 895:	learn: 0.4945277	total: 2m 1s	remaining: 14.1s
# 896:	learn: 0.4943923	total: 2m 1s	remaining: 14s
# 897:	learn: 0.4943568	total: 2m 1s	remaining: 13.8s
# 898:	learn: 0.4942713	total: 2m 2s	remaining: 13.7s
# 899:	learn: 0.4942118	total: 2m 2s	remaining: 13.6s
# 900:	learn: 0.4940934	total: 2m 2s	remaining: 13.4s
# 901:	learn: 0.4940467	total: 2m 2s	remaining: 13.3s
# 902:	learn: 0.4939729	total: 2m 2s	remaining: 13.2s
# 903:	learn: 0.4937905	total: 2m 2s	remaining: 13s
# 904:	learn: 0.4937140	total: 2m 2s	remaining: 12.9s
# 905:	learn: 0.4936252	total: 2m 2s	remaining: 12.8s
# 906:	learn: 0.4935664	total: 2m 3s	remaining: 12.6s
# 907:	learn: 0.4934825	total: 2m 3s	remaining: 12.5s
# 908:	learn: 0.4933736	total: 2m 3s	remaining: 12.4s
# 909:	learn: 0.4932864	total: 2m 3s	remaining: 12.2s
# 910:	learn: 0.4931574	total: 2m 3s	remaining: 12.1s
# 911:	learn: 0.4930419	total: 2m 3s	remaining: 11.9s
# 912:	learn: 0.4929294	total: 2m 3s	remaining: 11.8s
# 913:	learn: 0.4928366	total: 2m 4s	remaining: 11.7s
# 914:	learn: 0.4927784	total: 2m 4s	remaining: 11.5s
# 915:	learn: 0.4926683	total: 2m 4s	remaining: 11.4s
# 916:	learn: 0.4925898	total: 2m 4s	remaining: 11.3s
# 917:	learn: 0.4925120	total: 2m 4s	remaining: 11.1s
# 918:	learn: 0.4924481	total: 2m 4s	remaining: 11s
# 919:	learn: 0.4923274	total: 2m 4s	remaining: 10.9s
# 920:	learn: 0.4922604	total: 2m 4s	remaining: 10.7s
# 921:	learn: 0.4922082	total: 2m 5s	remaining: 10.6s
# 922:	learn: 0.4921574	total: 2m 5s	remaining: 10.4s
# 923:	learn: 0.4920795	total: 2m 5s	remaining: 10.3s
# 924:	learn: 0.4919558	total: 2m 5s	remaining: 10.2s
# 925:	learn: 0.4918556	total: 2m 5s	remaining: 10s
# 926:	learn: 0.4916650	total: 2m 5s	remaining: 9.91s
# 927:	learn: 0.4915811	total: 2m 5s	remaining: 9.77s
# 928:	learn: 0.4915316	total: 2m 6s	remaining: 9.63s
# 929:	learn: 0.4914481	total: 2m 6s	remaining: 9.5s
# 930:	learn: 0.4913678	total: 2m 6s	remaining: 9.36s
# 931:	learn: 0.4911685	total: 2m 6s	remaining: 9.23s
# 932:	learn: 0.4910528	total: 2m 6s	remaining: 9.09s
# 933:	learn: 0.4909050	total: 2m 6s	remaining: 8.96s
# 934:	learn: 0.4908503	total: 2m 6s	remaining: 8.82s
# 935:	learn: 0.4907467	total: 2m 7s	remaining: 8.68s
# 936:	learn: 0.4906731	total: 2m 7s	remaining: 8.55s
# 937:	learn: 0.4905840	total: 2m 7s	remaining: 8.41s
# 938:	learn: 0.4904279	total: 2m 7s	remaining: 8.28s
# 939:	learn: 0.4903529	total: 2m 7s	remaining: 8.14s
# 940:	learn: 0.4903090	total: 2m 7s	remaining: 8.01s
# 941:	learn: 0.4902202	total: 2m 7s	remaining: 7.87s
# 942:	learn: 0.4901233	total: 2m 7s	remaining: 7.73s
# 943:	learn: 0.4900687	total: 2m 8s	remaining: 7.6s
# 944:	learn: 0.4899274	total: 2m 8s	remaining: 7.46s
# 945:	learn: 0.4898559	total: 2m 8s	remaining: 7.33s
# 946:	learn: 0.4897503	total: 2m 8s	remaining: 7.19s
# 947:	learn: 0.4896754	total: 2m 8s	remaining: 7.05s
# 948:	learn: 0.4894799	total: 2m 8s	remaining: 6.92s
# 949:	learn: 0.4894063	total: 2m 8s	remaining: 6.78s
# 950:	learn: 0.4893069	total: 2m 9s	remaining: 6.65s
# 951:	learn: 0.4892262	total: 2m 9s	remaining: 6.51s
# 952:	learn: 0.4891521	total: 2m 9s	remaining: 6.38s
# 953:	learn: 0.4890922	total: 2m 9s	remaining: 6.24s
# 954:	learn: 0.4890211	total: 2m 9s	remaining: 6.11s
# 955:	learn: 0.4889323	total: 2m 9s	remaining: 5.97s
# 956:	learn: 0.4888440	total: 2m 9s	remaining: 5.83s
# 957:	learn: 0.4887409	total: 2m 9s	remaining: 5.7s
# 958:	learn: 0.4885864	total: 2m 10s	remaining: 5.56s
# 959:	learn: 0.4884530	total: 2m 10s	remaining: 5.43s
# 960:	learn: 0.4883845	total: 2m 10s	remaining: 5.29s
# 961:	learn: 0.4883026	total: 2m 10s	remaining: 5.16s
# 962:	learn: 0.4882481	total: 2m 10s	remaining: 5.02s
# 963:	learn: 0.4881414	total: 2m 10s	remaining: 4.88s
# 964:	learn: 0.4880467	total: 2m 10s	remaining: 4.75s
# 965:	learn: 0.4879304	total: 2m 11s	remaining: 4.61s
# 966:	learn: 0.4878839	total: 2m 11s	remaining: 4.48s
# 967:	learn: 0.4877517	total: 2m 11s	remaining: 4.34s
# 968:	learn: 0.4876625	total: 2m 11s	remaining: 4.21s
# 969:	learn: 0.4875422	total: 2m 11s	remaining: 4.07s
# 970:	learn: 0.4874241	total: 2m 11s	remaining: 3.93s
# 971:	learn: 0.4873152	total: 2m 11s	remaining: 3.8s
# 972:	learn: 0.4872240	total: 2m 11s	remaining: 3.66s
# 973:	learn: 0.4871772	total: 2m 12s	remaining: 3.53s
# 974:	learn: 0.4870626	total: 2m 12s	remaining: 3.39s
# 975:	learn: 0.4869275	total: 2m 12s	remaining: 3.25s
# 976:	learn: 0.4868394	total: 2m 12s	remaining: 3.12s
# 977:	learn: 0.4867354	total: 2m 12s	remaining: 2.98s
# 978:	learn: 0.4865932	total: 2m 12s	remaining: 2.85s
# 979:	learn: 0.4865454	total: 2m 12s	remaining: 2.71s
# 980:	learn: 0.4864308	total: 2m 13s	remaining: 2.58s
# 981:	learn: 0.4863889	total: 2m 13s	remaining: 2.44s
# 982:	learn: 0.4862980	total: 2m 13s	remaining: 2.31s
# 983:	learn: 0.4862317	total: 2m 13s	remaining: 2.17s
# 984:	learn: 0.4861627	total: 2m 13s	remaining: 2.03s
# 985:	learn: 0.4861017	total: 2m 13s	remaining: 1.9s
# 986:	learn: 0.4860044	total: 2m 13s	remaining: 1.76s
# 987:	learn: 0.4859438	total: 2m 14s	remaining: 1.63s
# 988:	learn: 0.4858487	total: 2m 14s	remaining: 1.49s
# 989:	learn: 0.4857865	total: 2m 14s	remaining: 1.36s
# 990:	learn: 0.4856490	total: 2m 14s	remaining: 1.22s
# 991:	learn: 0.4855842	total: 2m 14s	remaining: 1.08s
# 992:	learn: 0.4854483	total: 2m 14s	remaining: 949ms
# 993:	learn: 0.4853518	total: 2m 14s	remaining: 814ms
# 994:	learn: 0.4851650	total: 2m 14s	remaining: 678ms
# 995:	learn: 0.4850791	total: 2m 15s	remaining: 543ms
# 996:	learn: 0.4849613	total: 2m 15s	remaining: 407ms
# 997:	learn: 0.4848714	total: 2m 15s	remaining: 271ms
# 998:	learn: 0.4847556	total: 2m 15s	remaining: 136ms
# 999:	learn: 0.4846681	total: 2m 15s	remaining: 0us
# trained

# %%
import joblib
model.save_model('models/regression/regression.cbm')
for key, encoder in encoders.items():
    filename = f"models/regression/{key}_encoder.joblib"
    joblib.dump(encoder, filename)
    print(f"Saved encoder to {filename}")
joblib.dump(premium_scaler,'models/regression/premium_scaler.joblib')
joblib.dump(experience_scaler,'models/regression/experience_scaler.joblib')
joblib.dump(salary_scaler,'models/regression/salary_scaler.joblib')
joblib.dump(places_scaler,'models/regression/places_scaler.joblib')
# Out:
# Saved encoder to academic_degree_encoder.joblib
# Saved encoder to accommodation_type_encoder.joblib
# Saved encoder to bonus_type_encoder.joblib
# Saved encoder to measure_type_encoder.joblib
# Saved encoder to busy_type_encoder.joblib
# Saved encoder to education_encoder.joblib
# Saved encoder to original_source_type_encoder.joblib
# Saved encoder to company_business_size_encoder.joblib
# Saved encoder to schedule_type_encoder.joblib
# Saved encoder to social_protected_ids_encoder.joblib
# Saved encoder to source_type_encoder.joblib
# Saved encoder to state_region_code_encoder.joblib
# Saved encoder to status_encoder.joblib
# Saved encoder to transport_compensation_encoder.joblib
# Saved encoder to vacancy_benefit_ids_encoder.joblib
# Saved encoder to professionalSphereName_encoder.joblib
# Saved encoder to federalDistrictCode_encoder.joblib
# Saved encoder to code_professional_sphere_encoder.joblib
# Saved encoder to required_drive_license_encoder.joblib
# Saved encoder to languageKnowledge_encoder.joblib
# ['places_scaler.joblib']
